# %% [raw]
# For Ethan
#
# is there a way to "turn off" a module (export?)
# help reading in oscars db

# %%
# Load necessary libraries

from imdbpie import Imdb as ip
import csv
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from IPython.core.display import HTML

# %%
# Get data on top 250 movies

imdb = Imdb()
imdb = Imdb(anonymize=True) # to proxy requests

imdb.top_250()
# Out:
# [{u'can_rate': True,
#   u'image': {u'height': 1388,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_.jpg',
#    u'width': 933},
#   u'num_votes': 1721329,
#   u'rating': 9.3,
#   u'tconst': u'tt0111161',
#   u'title': u'The Shawshank Redemption',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 1129,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNTUxOTdjMDMtMWY1MC00MjkxLTgxYTMtYTM1MjU5ZTJlNTZjXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_.jpg',
#    u'width': 798},
#   u'num_votes': 1176430,
#   u'rating': 9.2,
#   u'tconst': u'tt0068646',
#   u'title': u'The Godfather',
#   u'type': u'feature',
#   u'year': u'1972'},
#  {u'can_rate': True,
#   u'image': {u'height': 1140,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNDVjZjgxNTgtMGNhMC00YWU0LTg0YTQtNTkxNzBjMDBkNWYyXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_.jpg',
#    u'width': 800},
# ...

# %%
# from IPython.core.display import HTML
# HTML(r.content.decode('utf-8'))

# %%
top_pull = (pd.DataFrame(imdb.top_250()))
top_pull.head()

top_pull.to_csv('/Users/EKandTower/GA-DSI/projects/projects-weekly/project-06/top_pull',\
                sep='\t', encoding='utf-8')

# %% [raw]
# Pull of top 250 DB gives us 5 useful columns:
#
# num_votes (number of users rating the movie)
# rating (imdb user rating)
# tconst (the IMDb Title ID)
# title (title of the movie
# year (year it was released)
#
# using two imdb apis with too much crossover in naming so saved top 250 DB to use in separate notebook.
