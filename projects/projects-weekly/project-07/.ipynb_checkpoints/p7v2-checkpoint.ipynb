# %% [raw]
# Can CPA be used to figure out which airports are the issue? isn't that a classification problem? wouldn't CPA be used more to project what the delays at an airport are? # cpa is used to create feature clusters that can be used for classifications / regressions.
#
# Why are we being asked to make dummy data if you shouldn't use dummy data in CPA? # you use it for the cluster, not for the cpa
#
# Why are we being asked about unique values? # dumb question
#
# MinMax or standard?
#
# Is there a reason to be looking at earlier years (if not doing a trend)?
#
# How tricky to make a trend? Don't want to have a major time-suck with little utility (like I always do).

# %% [raw]
# For a more streamlined (operationally efficient) / educational experience I have forgone doing the thing that my analystical head says is absolutely necessary for this project--creating change scores to show what airports have improved / worsened. You will see that I have eliminated every year but 2014 in this analysis. Prior years are only important to show trends.

# %% [markdown]
# # Project 7
#
# In this project, you will implement the the clustering techniques that you've learned this week.
#
# #### Step 1: Load the python libraries that you will need for this project

# %%
import pandas as pd 
import matplotlib as plt
import numpy as np
import sklearn
import psycopg2 as psy
import csv
from sqlalchemy import create_engine
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
# %matplotlib inline
from sklearn.decomposition import PCA 
import pandas as pd
from pandas.io import sql
import pandas as pd
import numpy as np
# %matplotlib inline
from sklearn.feature_extraction.text import CountVectorizer

import matplotlib.pyplot as plt

# %% [markdown]
# #### Step 2: Examine your data

# %%
cancel = pd.read_csv("/Users/EKandTower/GA-DSI/projects/projects-weekly/project-07/\
assets/airport_cancellations.csv")

ops = pd.read_csv("/Users/EKandTower/GA-DSI/projects/projects-weekly/project-07/\
assets/Airport_operations.csv")

ap = pd.read_csv("/Users/EKandTower/GA-DSI/projects/projects-weekly/project-07/\
assets/airports.csv")

# ajbentley

# EKandTower

# %% [markdown]
# ### Intro: Write a problem statement / aim for this project

# %% [markdown]
# Objective: Your task is to understand the distribution, characteristics, and components of individual airports operations that are leading to these delays.
#
#
# First step is to identify which airports are the "problem children." We can do this with PCA and clustering.
#
# Will run naive PCA and pare down on features to reduce overfitting until we can get at least 70% explained on 3 features. Then we'll use those features to cluster.
#
# Clustering on PCAs should show what airports have higher than normal delay times and whose operations have been flat or worsening.
#
# Once we ID what airports are the problems we can figure out what they have in common.
#
# Once they have been identified we can do classification to find out what the specific metrics are that are impacting their efficiancy.

# %% [markdown]
# ### Part 1: Create a PostgreSQL database

# %% [markdown]
# #### 1. Let's create a database where we can house our airport data

# %%
# import sqlite3
# sqlite_db = 'dsi2-db.sqlite'
# conn = sqlite3.connect(sqlite_db)
# c = conn.cursor()

# print "done"

# %% [raw]
# DB created in Navicat

# %%
# con = None
# con = psy.connect(database='Default', user='postgres')

# %%
# engine = create_engine('postgresql://localhost:5432/apdb')
# cancel.to_sql('cancel', engine, if_exists='replace')
# operations.to_sql('ops', engine, if_exists='replace')
# apdb.to_sql('apdb', engine, if_exists='replace')
# %load_ext sql

# %% [markdown]
# Load our csv files into tables

# %% [markdown]
# Join airport_cancellations.csv and airports.csv into one table

# %%
cancel.rename(columns ={'Airport':'AP_NAME'}, inplace=True)

# %%
df = cancel.join(ap, rsuffix='ap')
df.pop('AP_NAMEap');

# %%
df = df.join(ops, rsuffix='ops')

# %% [markdown]
# Query the database for our intial data

# %% [markdown]
# #### 1.2 What are the risks and assumptions of our data?

# %% [markdown]
# While there is considerable information presented there is a massive amount of information that feels like it most be colinear (several flavors of delays and arrivals, all of which probably correlate highly).
#
# There's also data that are missing. It would be significant to see meteorological data, which I have to imagine the FAA collects, to show whether temperature and precipitation have seen significant shifts in this time.
#
# It could be useful to see whether there is any difference in monthly numbers. Has tourism increased?
#
# Once we get down to the individual airports that we need to consider it would be good to see whether there have been changes in the airlines serving the airport or in the sources / destinations of the planes. If flights from Denver tend to be late and they've just started a new direct flight from Denver to DC then the delays in DC would change.

# %% [markdown]
# ### Part 2: Exploratory Data Analysis

# %% [markdown]
# #### 2.1 Plot and Describe the Data

# %%
df.describe()
# Out:
#               Year  Departure Cancellations  Arrival Cancellations  \
# count   805.000000               805.000000             805.000000
# mean   2008.986335              1292.038509            1333.124224
# std       3.158116              1835.961943            1975.224868
# min    2004.000000                 0.000000               0.000000
# 25%    2006.000000               349.000000             314.000000
# 50%    2009.000000               663.000000             642.000000
# 75%    2012.000000              1472.000000            1523.000000
# max    2014.000000             16618.000000           17571.000000
#
#        Departure Diversions  Arrival Diversions          Key    Latitude  \
# count            805.000000          805.000000   805.000000  805.000000
# mean             173.315528          169.413665  2488.650932   30.522748
# std              172.345539          228.521615  1607.433809    2.806227
# min                0.000000            0.000000   254.000000   17.701556
# 25%               62.000000           41.000000   880.000000   29.607333
# 50%              110.000000           84.000000  2900.000000   31.179278
# 75%              236.000000          190.000000  3319.000000   32.493417
# max             1064.000000         1948.000000  5251.000000   33.303458
#
#         Longitude         year  departures for metric computation  \
# count  805.000000   805.000000                         805.000000
# mean   -93.577507  2009.014907                      111331.108075
# std     12.880292     3.152394                       99041.431112
# min   -177.381308  2004.000000                         261.000000
# 25%    -97.969472  2006.000000                       39279.000000
# 50%    -93.745023  2009.000000                       73741.000000
# 75%    -84.557425  2012.000000                      166455.000000
# max    -64.801722  2014.000000                      491826.000000
#
#                   ...              percent on-time airport departures  \
# count             ...                                      805.000000
# mean              ...                                        0.719039
# std               ...                                        0.088554
# min               ...                                        0.245700
# 25%               ...                                        0.686300
# 50%               ...                                        0.736200
# 75%               ...                                        0.770700
# max               ...                                        0.897400
#
#        percent on-time gate arrivals  average_gate_departure_delay  \
# count                     805.000000                    805.000000
# mean                        0.760144                     13.299888
# std                         0.068339                      4.076106
# min                         0.349500                      5.350000
# 25%                         0.738100                     10.950000
# 50%                         0.769300                     12.670000
# 75%                         0.797500                     14.820000
# max                         0.880300                     40.800000
#
#        average_taxi_out_time  average taxi out delay  \
# count             805.000000              805.000000
# mean               13.813453                3.604907
# std                 3.836060                2.397139
# min                 7.040000                0.000000
# 25%                11.330000                2.230000
# 50%                12.930000                3.030000
# 75%                15.720000                4.190000
# max                35.760000               18.940000
#
#        average airport departure delay  average airborne delay  \
# count                       805.000000              805.000000
# mean                         16.059615                2.930112
# std                           4.937230                1.199621
# min                           6.290000                0.950000
# 25%                          12.980000                2.060000
# 50%                          15.240000                2.660000
# 75%                          17.850000                3.620000
# max                          40.870000                7.820000
#
#        average taxi in delay  average block delay  average gate arrival delay
# count             805.000000           805.000000                  805.000000
# mean                1.385006             3.322807                   13.743565
# std                 0.879909             1.029183                    3.907379
# min                 0.000000             1.230000                    6.330000
# 25%                 0.820000             2.630000                   11.270000
# 50%                 1.120000             3.150000                   13.070000
# 75%                 1.770000             3.850000                   15.190000
# max                 6.180000             7.520000                   34.280000
#
# [8 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 805 entries, 0 to 804
# Data columns (total 33 columns):
# AP_NAME                               805 non-null object
# Year                                  805 non-null float64
# Departure Cancellations               805 non-null float64
# Arrival Cancellations                 805 non-null float64
# Departure Diversions                  805 non-null float64
# Arrival Diversions                    805 non-null float64
# Key                                   805 non-null float64
# LocID                                 804 non-null object
# ALIAS                                 631 non-null object
# Facility Type                         805 non-null object
# FAA REGION                            805 non-null object
# COUNTY                                805 non-null object
# CITY                                  805 non-null object
# STATE                                 805 non-null object
# AP Type                               805 non-null object
# Latitude                              805 non-null float64
# Longitude                             805 non-null float64
# Boundary Data Available               805 non-null object
# airport                               805 non-null object
# year                                  805 non-null int64
# departures for metric computation     805 non-null int64
# arrivals for metric computation       805 non-null int64
# percent on-time gate departures       805 non-null float64
# percent on-time airport departures    805 non-null float64
# percent on-time gate arrivals         805 non-null float64
# average_gate_departure_delay          805 non-null float64
# average_taxi_out_time                 805 non-null float64
# average taxi out delay                805 non-null float64
# average airport departure delay       805 non-null float64
# average airborne delay                805 non-null float64
# average taxi in delay                 805 non-null float64
# average block delay                   805 non-null float64
# average gate arrival delay            805 non-null float64
# dtypes: float64(19), int64(3), object(11)
# memory usage: 207.6+ KB

# %%
# df['AP_NAME'] = LabelEncoder().fit_transform(df['AP_NAME'])
df['FAA REGION'] = LabelEncoder().fit_transform(df['FAA REGION'])
df['LocID'] = LabelEncoder().fit_transform(df['LocID'])

df['ALIAS'] = LabelEncoder().fit_transform(df['ALIAS'])
df['Facility Type'] = LabelEncoder().fit_transform(df['Facility Type'])
df['COUNTY'] = LabelEncoder().fit_transform(df['COUNTY'])
df['CITY'] = LabelEncoder().fit_transform(df['CITY'])
df['STATE'] = LabelEncoder().fit_transform(df['STATE'])
df['AP Type'] = LabelEncoder().fit_transform(df['AP Type'])
df['Boundary Data Available'] = LabelEncoder().fit_transform(df['Boundary Data Available'])
df['airport'] = LabelEncoder().fit_transform(df['airport'])

# %%
# making new db with only 2014 data. As indicated at the head of this document, my preferred analysis on this would\
# to just use 2014 and the change metrics. I think prior years' data are useful mostly for the change.

df14 = pd.DataFrame(df.loc[df['Year'] == 2014])
df14.head()
# Out:
#    AP_NAME    Year  Departure Cancellations  Arrival Cancellations  \
# 10     ABQ  2014.0                    315.0                  274.0
# 21     ANC  2014.0                    111.0                  162.0
# 32     ATL  2014.0                   5977.0                 6483.0
# 43     AUS  2014.0                    484.0                  435.0
# 54     BDL  2014.0                    467.0                  421.0
#
#     Departure Diversions  Arrival Diversions     Key  LocID  ALIAS  \
# 10                  66.0                37.0  2885.0    677     11
# 21                  74.0                28.0   982.0    570    421
# 32                 781.0               655.0  4196.0    788      0
# 43                  88.0                97.0  3282.0    628    482
# 54                  57.0                32.0  5145.0    693      0
#
#     Facility Type             ...              \
# 10              0             ...
# 21              0             ...
# 32              0             ...
# 43              0             ...
# 54              0             ...
#
#     percent on-time airport departures  percent on-time gate arrivals  \
# 10                              0.7148                         0.7320
# 21                              0.8074                         0.8600
# 32                              0.7134                         0.8123
# 43                              0.7382                         0.7222
# 54                              0.7605                         0.7569
#
#     average_gate_departure_delay  average_taxi_out_time  \
# 10                         14.30                  10.64
# 21                         11.33                  11.33
# 32                         11.99                  17.40
# 43                         14.16                  11.76
# 54                         12.64                  12.76
#
#     average taxi out delay  average airport departure delay  \
# 10                    2.41                            15.99
# 21                    1.33                            12.34
# 32                    4.92                            15.93
# 43                    2.06                            15.59
# 54                    2.58                            14.39
#
#     average airborne delay  average taxi in delay  average block delay  \
# 10                    1.73                   1.02                 2.40
# 21                    4.09                   0.54                 4.57
# 32                    2.74                   2.77                 3.21
# 43                    2.25                   1.08                 2.88
# 54                    2.34                   0.95                 2.64
#
#     average gate arrival delay
# 10                       14.72
# 21                       10.82
# 32                       12.42
# 43                       16.20
# 54                       14.79
#
# [5 rows x 33 columns]

# %%
# sns.pairplot(df14, kind="scatter", size=10)

# %% [raw]
# add regplots

# %% [markdown]
# #### Are there any unique values?

# %% [markdown]
# They're almost all unique values.'

# %% [markdown]
# ### Part 3: Data Mining

# %% [markdown]
# #### 3.1 Create Dummy Variables

# %%
# region_dummy = pd.get_dummies(df['FAA REGION'], prefix='Region')

# df = df.join(region_dummy)

# df.head()

# cv = CountVectorizer()
# data = cv.fit_transform(df.Genre).todense()
# columns = ['genre_'+c for c in cv.get_feature_names()]

# df['airport'] = LabelEncoder().fit_transform(df['airport'])
# df['airport'] = MinMaxScaler().fit_transform(df['airport'].astype(float).reshape(-1, 1))


# df.pop('ALIAS')
# df.pop('COUNTY')
# df.pop('CITY')
# df.pop('STATE')
# df.pop('Boundary Data Available')
# df.pop('year')
# df.pop('airport');
# df14.pop('ap_type')
# df14.pop('region')
# df14.pop('LocID')

# %% [markdown]
# #### 3.2 Format and Clean the Data

# %% [raw]
# change year, dep/arr info, regions into int
# pop alias, couty, city, state, boundary data
# again, find / compute /break out 10 year avg

# %%
# df.pop('Key');

# %%
# df.pop('ALIAS')
# df.pop('COUNTY')
# df.pop('CITY')
# df.pop('STATE')
# df.pop('Boundary Data Available')
# df.pop('year')
# df.pop('airport');

# %%
# df14.columns = ['airport','year','DCancel','ACancel','DDivert','ADivert','LocID','region','ap_type','Lat','Long','deps'\
#               ,'arr','pct_ont_gateD','pct_ont_airptD','pct_ont_gateA','avg_gate_Ddelay','avg_taxi_out',\
#               'avg_taxi_delay','avg_airptDdelay','avg_airborne_delay','avg_taxi_in_delay','avg_block_delay',\
#               'avg_gate_Adelay','Region_ASO','Region_ASW','Region_AWP']
# df14.head()

# %%
df14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 10 to 804
# Data columns (total 33 columns):
# AP_NAME                               72 non-null object
# Year                                  72 non-null float64
# Departure Cancellations               72 non-null float64
# Arrival Cancellations                 72 non-null float64
# Departure Diversions                  72 non-null float64
# Arrival Diversions                    72 non-null float64
# Key                                   72 non-null float64
# LocID                                 72 non-null int64
# ALIAS                                 72 non-null int64
# Facility Type                         72 non-null int64
# FAA REGION                            72 non-null int64
# COUNTY                                72 non-null int64
# CITY                                  72 non-null int64
# STATE                                 72 non-null int64
# AP Type                               72 non-null int64
# Latitude                              72 non-null float64
# Longitude                             72 non-null float64
# Boundary Data Available               72 non-null int64
# airport                               72 non-null int64
# year                                  72 non-null int64
# departures for metric computation     72 non-null int64
# arrivals for metric computation       72 non-null int64
# percent on-time gate departures       72 non-null float64
# percent on-time airport departures    72 non-null float64
# percent on-time gate arrivals         72 non-null float64
# average_gate_departure_delay          72 non-null float64
# average_taxi_out_time                 72 non-null float64
# average taxi out delay                72 non-null float64
# average airport departure delay       72 non-null float64
# average airborne delay                72 non-null float64
# average taxi in delay                 72 non-null float64
# average block delay                   72 non-null float64
# average gate arrival delay            72 non-null float64
# dtypes: float64(19), int64(13), object(1)
# memory usage: 19.1+ KB

# %%
# create more manageable list for visualizations 


dfn = ['Departure Cancellations','Arrival Cancellations','Departure Diversions','Arrival Diversions','Latitude'\
       ,'Longitude','departures for metric computation','arrivals for metric computation',\
       'percent on-time gate departures', 'percent on-time airport departures','percent on-time gate arrivals',\
       'average_taxi_out_time','average taxi out delay','average airport departure delay','average airborne delay',\
       'average taxi in delay','average block delay','average gate arrival delay' ]
dfn = pd.DataFrame(df14[dfn])
dfn.head()
# Out:
#     Departure Cancellations  Arrival Cancellations  Departure Diversions  \
# 10                    315.0                  274.0                  66.0
# 21                    111.0                  162.0                  74.0
# 32                   5977.0                 6483.0                 781.0
# 43                    484.0                  435.0                  88.0
# 54                    467.0                  421.0                  57.0
#
#     Arrival Diversions   Latitude   Longitude  \
# 10                37.0  18.439295  -66.002004
# 21                28.0  21.152886 -157.096256
# 32               655.0  25.778333  -80.170278
# 43                97.0  26.166194  -97.345889
# 54                32.0  26.562843  -97.437759
#
#     departures for metric computation  arrivals for metric computation  \
# 10                              33292                            33137
# 21                              71099                            66704
# 32                             428954                           428312
# 43                              60588                            60264
# 54                              39279                            39109
#
#     percent on-time gate departures  percent on-time airport departures  \
# 10                           0.7451                              0.7148
# 21                           0.8288                              0.8074
# 32                           0.7899                              0.7134
# 43                           0.7627                              0.7382
# 54                           0.7953                              0.7605
#
#     percent on-time gate arrivals  average_taxi_out_time  \
# 10                         0.7320                  10.64
# 21                         0.8600                  11.33
# 32                         0.8123                  17.40
# 43                         0.7222                  11.76
# 54                         0.7569                  12.76
#
#     average taxi out delay  average airport departure delay  \
# 10                    2.41                            15.99
# 21                    1.33                            12.34
# 32                    4.92                            15.93
# 43                    2.06                            15.59
# 54                    2.58                            14.39
#
#     average airborne delay  average taxi in delay  average block delay  \
# 10                    1.73                   1.02                 2.40
# 21                    4.09                   0.54                 4.57
# 32                    2.74                   2.77                 3.21
# 43                    2.25                   1.08                 2.88
# 54                    2.34                   0.95                 2.64
#
#     average gate arrival delay
# 10                       14.72
# 21                       10.82
# 32                       12.42
# 43                       16.20
# 54                       14.79

# %% [markdown]
# ### Part 4: Define the Data

# %% [markdown]
# #### 4.1 Confirm that the dataset has a normal distribution. How can you tell?

# %%
dfn.describe()
# Out:
#        Departure Cancellations  Arrival Cancellations  Departure Diversions  \
# count                72.000000              72.000000             72.000000
# mean               1372.652778            1413.902778            171.111111
# std                1997.878573            2149.679014            178.508733
# min                  17.000000              11.000000              3.000000
# 25%                 428.000000             388.250000             56.500000
# 50%                 633.000000             643.000000             88.000000
# 75%                1365.250000            1489.250000            211.500000
# max               13454.000000           14355.000000            781.000000
#
#        Arrival Diversions   Latitude   Longitude  \
# count           72.000000  72.000000   72.000000
# mean           163.458333  30.596586  -94.599805
# std            217.219493   2.644913   12.238074
# min              7.000000  18.439295 -157.096256
# 25%             34.750000  29.625690  -98.434040
# 50%             82.500000  31.175144  -94.225836
# 75%            176.500000  32.487121  -87.164354
# max           1164.000000  33.303458  -66.002004
#
#        departures for metric computation  arrivals for metric computation  \
# count                          72.000000                        72.000000
# mean                        99313.375000                     98989.277778
# std                         88534.604766                     88426.863627
# min                           729.000000                       752.000000
# 25%                         34276.250000                     33970.750000
# 50%                         64522.000000                     64461.000000
# 75%                        161125.250000                    159243.750000
# max                        428954.000000                    428312.000000
#
#        percent on-time gate departures  percent on-time airport departures  \
# count                        72.000000                           72.000000
# mean                          0.752960                            0.704911
# std                           0.081974                            0.088062
# min                           0.318500                            0.317000
# 25%                           0.722600                            0.670500
# 50%                           0.767050                            0.716000
# 75%                           0.796575                            0.753750
# max                           0.900700                            0.888100
#
#        percent on-time gate arrivals  average_taxi_out_time  \
# count                      72.000000              72.000000
# mean                        0.751256              13.524861
# std                         0.070395               3.256936
# min                         0.398200               8.520000
# 25%                         0.722800              11.245000
# 50%                         0.755100              12.765000
# 75%                         0.782650              15.117500
# max                         0.878400              25.100000
#
#        average taxi out delay  average airport departure delay  \
# count               72.000000                        72.000000
# mean                 3.183472                        16.863333
# std                  1.814836                         4.616593
# min                  0.110000                         6.440000
# 25%                  2.102500                        14.295000
# 50%                  2.615000                        16.475000
# 75%                  3.962500                        19.157500
# max                 11.210000                        35.400000
#
#        average airborne delay  average taxi in delay  average block delay  \
# count               72.000000              72.000000            72.000000
# mean                 2.660000               1.335833             3.200694
# std                  0.981281               0.853547             0.770649
# min                  1.260000               0.000000             1.840000
# 25%                  1.967500               0.837500             2.637500
# 50%                  2.440000               1.150000             3.080000
# 75%                  3.130000               1.732500             3.767500
# max                  6.410000               4.950000             5.130000
#
#        average gate arrival delay
# count                   72.000000
# mean                    14.472778
# std                      3.759929
# min                      7.180000
# 25%                     12.280000
# 50%                     14.550000
# 75%                     16.225000
# max                     30.940000

# %%
dfn.hist(figsize=(10,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x118a14b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118d046d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10a4d8dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a83d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118b16650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118e916d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119016590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119095910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x119118890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119184850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119206b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119269ad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1192f8090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1192a1490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119558d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1195e9090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1196488d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1196ca950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119720710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bb91a90>]], dtype=object)

# %% [raw]
# most data have strong right skews, some have strong left skews. then there's average airport departure delay which is nearly textbook normal.

# %% [markdown]
# #### 4.2 Find correlations in the data

# %%
print df14.corr()
# Out:
#                                     Year  Departure Cancellations  \
# Year                                 NaN                      NaN
# Departure Cancellations              NaN                 1.000000
# Arrival Cancellations                NaN                 0.998869
# Departure Diversions                 NaN                 0.814193
# Arrival Diversions                   NaN                 0.815058
# Key                                  NaN                -0.055253
# LocID                                NaN                 0.084503
# ALIAS                                NaN                 0.175546
# Facility Type                        NaN                      NaN
# FAA REGION                           NaN                 0.024928
# COUNTY                               NaN                -0.117975
# CITY                                 NaN                -0.062351
# STATE                                NaN                 0.039571
# AP Type                              NaN                -0.127395
# Latitude                             NaN                -0.038082
# Longitude                            NaN                 0.090160
# Boundary Data Available              NaN                 0.132498
# airport                              NaN                -0.135740
# year                                 NaN                 0.188327
# departures for metric computation    NaN                 0.412886
# arrivals for metric computation      NaN                 0.412948
# percent on-time gate departures      NaN                 0.001853
# percent on-time airport departures   NaN                -0.063333
# percent on-time gate arrivals        NaN                 0.051384
# average_gate_departure_delay         NaN                 0.047975
# average_taxi_out_time                NaN                 0.186542
# average taxi out delay               NaN                 0.210018
# average airport departure delay      NaN                 0.123237
# average airborne delay               NaN                -0.001808
# average taxi in delay                NaN                 0.374938
# average block delay                  NaN                -0.008727
# average gate arrival delay           NaN                 0.002457
#
#                                     Arrival Cancellations  \
# Year                                                  NaN
# Departure Cancellations                          0.998869
# Arrival Cancellations                            1.000000
# Departure Diversions                             0.828012
# Arrival Diversions                               0.821183
# Key                                             -0.061563
# LocID                                            0.084829
# ALIAS                                            0.174528
# Facility Type                                         NaN
# FAA REGION                                       0.018997
# COUNTY                                          -0.122396
# CITY                                            -0.058627
# STATE                                            0.032821
# AP Type                                         -0.125727
# Latitude                                        -0.039263
# Longitude                                        0.090394
# Boundary Data Available                          0.136457
# airport                                         -0.134586
# year                                             0.182523
# departures for metric computation                0.417236
# arrivals for metric computation                  0.417307
# percent on-time gate departures                 -0.002757
# percent on-time airport departures              -0.069111
# percent on-time gate arrivals                    0.048858
# average_gate_departure_delay                     0.052579
# average_taxi_out_time                            0.188936
# average taxi out delay                           0.211663
# average airport departure delay                  0.128794
# average airborne delay                           0.006306
# average taxi in delay                            0.374021
# average block delay                             -0.006803
# average gate arrival delay                       0.006280
#
#                                     Departure Diversions  Arrival Diversions  \
# Year                                                 NaN                 NaN
# Departure Cancellations                         0.814193            0.815058
# Arrival Cancellations                           0.828012            0.821183
# Departure Diversions                            1.000000            0.865897
# Arrival Diversions                              0.865897            1.000000
# Key                                            -0.071557           -0.027638
# LocID                                          -0.023972            0.027061
# ALIAS                                           0.116877            0.171246
# Facility Type                                        NaN                 NaN
# FAA REGION                                     -0.041600           -0.008626
# COUNTY                                         -0.130388           -0.039663
# CITY                                           -0.151800           -0.106759
# STATE                                           0.015628            0.077137
# AP Type                                        -0.169848           -0.192597
# Latitude                                       -0.045792           -0.036021
# Longitude                                       0.111733            0.109554
# Boundary Data Available                         0.138477            0.116532
# airport                                        -0.125760           -0.154860
# year                                            0.099653            0.194050
# departures for metric computation               0.532223            0.527499
# arrivals for metric computation                 0.532186            0.528675
# percent on-time gate departures                 0.012497           -0.024786
# percent on-time airport departures             -0.065786           -0.073531
# percent on-time gate arrivals                   0.059721            0.045464
# average_gate_departure_delay                    0.043776            0.084311
# average_taxi_out_time                           0.271659            0.180333
# average taxi out delay                          0.238494            0.176313
# average airport departure delay                 0.129797            0.144979
# average airborne delay                          0.078697            0.009776
# average taxi in delay                           0.414007            0.495312
# average block delay                             0.118190            0.131565
# average gate arrival delay                      0.017786            0.036263
#
#                                          Key     LocID     ALIAS  \
# Year                                     NaN       NaN       NaN
# Departure Cancellations            -0.055253  0.084503  0.175546
# Arrival Cancellations              -0.061563  0.084829  0.174528
# Departure Diversions               -0.071557 -0.023972  0.116877
# Arrival Diversions                 -0.027638  0.027061  0.171246
# Key                                 1.000000  0.025412 -0.395485
# LocID                               0.025412  1.000000  0.288488
# ALIAS                              -0.395485  0.288488  1.000000
# Facility Type                            NaN       NaN       NaN
# FAA REGION                          0.146492  0.126397 -0.056386
# COUNTY                              0.063459  0.032089  0.000361
# CITY                                0.166371  0.393520  0.179868
# STATE                               0.737084  0.067871 -0.013957
# AP Type                            -0.000059 -0.004021 -0.051112
# Latitude                           -0.121794 -0.225711 -0.110273
# Longitude                          -0.031894 -0.077085  0.007245
# Boundary Data Available            -0.826753  0.051567  0.623698
# airport                            -0.143146 -0.185673 -0.189838
# year                                0.029060  0.062172  0.153979
# departures for metric computation   0.021753  0.153994  0.211818
# arrivals for metric computation     0.022171  0.156146  0.210999
# percent on-time gate departures    -0.081467 -0.061717  0.050510
# percent on-time airport departures -0.113082 -0.101734  0.008774
# percent on-time gate arrivals      -0.107426  0.002794  0.081239
# average_gate_departure_delay        0.057374  0.024802 -0.012958
# average_taxi_out_time               0.024406 -0.024667  0.135377
# average taxi out delay              0.052712  0.059949  0.112213
# average airport departure delay     0.074458  0.052084  0.032102
# average airborne delay              0.004860  0.161368  0.115175
# average taxi in delay               0.073874  0.156361  0.229292
# average block delay                 0.017673 -0.133575  0.113839
# average gate arrival delay          0.092495 -0.021481  0.014193
#
#                                     Facility Type  FAA REGION  \
# Year                                          NaN         NaN
# Departure Cancellations                       NaN    0.024928
# Arrival Cancellations                         NaN    0.018997
# Departure Diversions                          NaN   -0.041600
# Arrival Diversions                            NaN   -0.008626
# Key                                           NaN    0.146492
# LocID                                         NaN    0.126397
# ALIAS                                         NaN   -0.056386
# Facility Type                                 NaN         NaN
# FAA REGION                                    NaN    1.000000
# COUNTY                                        NaN    0.129402
# CITY                                          NaN   -0.010958
# STATE                                         NaN    0.210213
# AP Type                                       NaN    0.085917
# Latitude                                      NaN    0.071239
# Longitude                                     NaN   -0.842395
# Boundary Data Available                       NaN   -0.070678
# airport                                       NaN    0.128745
# year                                          NaN   -0.229319
# departures for metric computation             NaN    0.007008
# arrivals for metric computation               NaN    0.005504
# percent on-time gate departures               NaN    0.155519
# percent on-time airport departures            NaN    0.161347
# percent on-time gate arrivals                 NaN    0.079726
# average_gate_departure_delay                  NaN   -0.149806
# average_taxi_out_time                         NaN    0.035129
# average taxi out delay                        NaN   -0.009990
# average airport departure delay               NaN   -0.149845
# average airborne delay                        NaN    0.156534
# average taxi in delay                         NaN    0.069103
# average block delay                           NaN    0.321391
# average gate arrival delay                    NaN   -0.051720
#
#                                                ...              \
# Year                                           ...
# Departure Cancellations                        ...
# Arrival Cancellations                          ...
# Departure Diversions                           ...
# Arrival Diversions                             ...
# Key                                            ...
# LocID                                          ...
# ALIAS                                          ...
# Facility Type                                  ...
# FAA REGION                                     ...
# COUNTY                                         ...
# CITY                                           ...
# STATE                                          ...
# AP Type                                        ...
# Latitude                                       ...
# Longitude                                      ...
# Boundary Data Available                        ...
# airport                                        ...
# year                                           ...
# departures for metric computation              ...
# arrivals for metric computation                ...
# percent on-time gate departures                ...
# percent on-time airport departures             ...
# percent on-time gate arrivals                  ...
# average_gate_departure_delay                   ...
# average_taxi_out_time                          ...
# average taxi out delay                         ...
# average airport departure delay                ...
# average airborne delay                         ...
# average taxi in delay                          ...
# average block delay                            ...
# average gate arrival delay                     ...
#
#                                     percent on-time airport departures  \
# Year                                                               NaN
# Departure Cancellations                                      -0.063333
# Arrival Cancellations                                        -0.069111
# Departure Diversions                                         -0.065786
# Arrival Diversions                                           -0.073531
# Key                                                          -0.113082
# LocID                                                        -0.101734
# ALIAS                                                         0.008774
# Facility Type                                                      NaN
# FAA REGION                                                    0.161347
# COUNTY                                                        0.242906
# CITY                                                          0.068403
# STATE                                                        -0.096631
# AP Type                                                      -0.043166
# Latitude                                                     -0.029427
# Longitude                                                    -0.122916
# Boundary Data Available                                       0.055081
# airport                                                       0.064317
# year                                                         -0.194160
# departures for metric computation                            -0.103937
# arrivals for metric computation                              -0.105964
# percent on-time gate departures                               0.911022
# percent on-time airport departures                            1.000000
# percent on-time gate arrivals                                 0.764483
# average_gate_departure_delay                                 -0.908154
# average_taxi_out_time                                        -0.268492
# average taxi out delay                                       -0.254685
# average airport departure delay                              -0.960860
# average airborne delay                                       -0.484434
# average taxi in delay                                        -0.108295
# average block delay                                          -0.346433
# average gate arrival delay                                   -0.777052
#
#                                     percent on-time gate arrivals  \
# Year                                                          NaN
# Departure Cancellations                                  0.051384
# Arrival Cancellations                                    0.048858
# Departure Diversions                                     0.059721
# Arrival Diversions                                       0.045464
# Key                                                     -0.107426
# LocID                                                    0.002794
# ALIAS                                                    0.081239
# Facility Type                                                 NaN
# FAA REGION                                               0.079726
# COUNTY                                                   0.117000
# CITY                                                     0.176080
# STATE                                                   -0.123913
# AP Type                                                 -0.041094
# Latitude                                                -0.074543
# Longitude                                               -0.088734
# Boundary Data Available                                  0.061532
# airport                                                 -0.060812
# year                                                    -0.050358
# departures for metric computation                        0.292487
# arrivals for metric computation                          0.290166
# percent on-time gate departures                          0.867758
# percent on-time airport departures                       0.764483
# percent on-time gate arrivals                            1.000000
# average_gate_departure_delay                            -0.882439
# average_taxi_out_time                                    0.102499
# average taxi out delay                                   0.186457
# average airport departure delay                         -0.768429
# average airborne delay                                  -0.217169
# average taxi in delay                                    0.226928
# average block delay                                     -0.359406
# average gate arrival delay                              -0.950755
#
#                                     average_gate_departure_delay  \
# Year                                                         NaN
# Departure Cancellations                                 0.047975
# Arrival Cancellations                                   0.052579
# Departure Diversions                                    0.043776
# Arrival Diversions                                      0.084311
# Key                                                     0.057374
# LocID                                                   0.024802
# ALIAS                                                  -0.012958
# Facility Type                                                NaN
# FAA REGION                                             -0.149806
# COUNTY                                                 -0.166752
# CITY                                                   -0.184214
# STATE                                                   0.103866
# AP Type                                                 0.066805
# Latitude                                               -0.010545
# Longitude                                               0.101380
# Boundary Data Available                                -0.012121
# airport                                                -0.081123
# year                                                    0.250869
# departures for metric computation                      -0.110023
# arrivals for metric computation                        -0.108185
# percent on-time gate departures                        -0.957675
# percent on-time airport departures                     -0.908154
# percent on-time gate arrivals                          -0.882439
# average_gate_departure_delay                            1.000000
# average_taxi_out_time                                   0.026270
# average taxi out delay                                 -0.052707
# average airport departure delay                         0.930601
# average airborne delay                                  0.294892
# average taxi in delay                                  -0.082909
# average block delay                                     0.321592
# average gate arrival delay                              0.892105
#
#                                     average_taxi_out_time  \
# Year                                                  NaN
# Departure Cancellations                          0.186542
# Arrival Cancellations                            0.188936
# Departure Diversions                             0.271659
# Arrival Diversions                               0.180333
# Key                                              0.024406
# LocID                                           -0.024667
# ALIAS                                            0.135377
# Facility Type                                         NaN
# FAA REGION                                       0.035129
# COUNTY                                          -0.124436
# CITY                                            -0.054911
# STATE                                            0.058265
# AP Type                                         -0.076500
# Latitude                                        -0.006811
# Longitude                                       -0.046184
# Boundary Data Available                          0.085523
# airport                                         -0.129195
# year                                             0.075837
# departures for metric computation                0.681210
# arrivals for metric computation                  0.679875
# percent on-time gate departures                  0.092480
# percent on-time airport departures              -0.268492
# percent on-time gate arrivals                    0.102499
# average_gate_departure_delay                     0.026270
# average_taxi_out_time                            1.000000
# average taxi out delay                           0.879397
# average airport departure delay                  0.343114
# average airborne delay                           0.629248
# average taxi in delay                            0.571928
# average block delay                              0.241858
# average gate arrival delay                       0.079991
#
#                                     average taxi out delay  \
# Year                                                   NaN
# Departure Cancellations                           0.210018
# Arrival Cancellations                             0.211663
# Departure Diversions                              0.238494
# Arrival Diversions                                0.176313
# Key                                               0.052712
# LocID                                             0.059949
# ALIAS                                             0.112213
# Facility Type                                          NaN
# FAA REGION                                       -0.009990
# COUNTY                                           -0.115497
# CITY                                              0.101215
# STATE                                             0.017280
# AP Type                                          -0.089027
# Latitude                                          0.018844
# Longitude                                         0.030595
# Boundary Data Available                           0.031756
# airport                                          -0.091131
# year                                              0.050299
# departures for metric computation                 0.638466
# arrivals for metric computation                   0.638496
# percent on-time gate departures                   0.158222
# percent on-time airport departures               -0.254685
# percent on-time gate arrivals                     0.186457
# average_gate_departure_delay                     -0.052707
# average_taxi_out_time                             0.879397
# average taxi out delay                            1.000000
# average airport departure delay                   0.313494
# average airborne delay                            0.556824
# average taxi in delay                             0.635614
# average block delay                               0.108179
# average gate arrival delay                       -0.014721
#
#                                     average airport departure delay  \
# Year                                                            NaN
# Departure Cancellations                                    0.123237
# Arrival Cancellations                                      0.128794
# Departure Diversions                                       0.129797
# Arrival Diversions                                         0.144979
# Key                                                        0.074458
# LocID                                                      0.052084
# ALIAS                                                      0.032102
# Facility Type                                                   NaN
# FAA REGION                                                -0.149845
# COUNTY                                                    -0.209155
# CITY                                                      -0.129105
# STATE                                                      0.106798
# AP Type                                                    0.033903
# Latitude                                                  -0.010270
# Longitude                                                  0.106987
# Boundary Data Available                                    0.000333
# airport                                                   -0.121511
# year                                                       0.267391
# departures for metric computation                          0.125534
# arrivals for metric computation                            0.127288
# percent on-time gate departures                           -0.855045
# percent on-time airport departures                        -0.960860
# percent on-time gate arrivals                             -0.768429
# average_gate_departure_delay                               0.930601
# average_taxi_out_time                                      0.343114
# average taxi out delay                                     0.313494
# average airport departure delay                            1.000000
# average airborne delay                                     0.486444
# average taxi in delay                                      0.146207
# average block delay                                        0.340110
# average gate arrival delay                                 0.839480
#
#                                     average airborne delay  \
# Year                                                   NaN
# Departure Cancellations                          -0.001808
# Arrival Cancellations                             0.006306
# Departure Diversions                              0.078697
# Arrival Diversions                                0.009776
# Key                                               0.004860
# LocID                                             0.161368
# ALIAS                                             0.115175
# Facility Type                                          NaN
# FAA REGION                                        0.156534
# COUNTY                                           -0.043995
# CITY                                             -0.026991
# STATE                                             0.011540
# AP Type                                           0.027379
# Latitude                                          0.059350
# Longitude                                        -0.300819
# Boundary Data Available                           0.041706
# airport                                           0.087199
# year                                             -0.099892
# departures for metric computation                 0.384965
# arrivals for metric computation                   0.384661
# percent on-time gate departures                  -0.255783
# percent on-time airport departures               -0.484434
# percent on-time gate arrivals                    -0.217169
# average_gate_departure_delay                      0.294892
# average_taxi_out_time                             0.629248
# average taxi out delay                            0.556824
# average airport departure delay                   0.486444
# average airborne delay                            1.000000
# average taxi in delay                             0.234797
# average block delay                               0.463519
# average gate arrival delay                        0.296419
#
#                                     average taxi in delay  \
# Year                                                  NaN
# Departure Cancellations                          0.374938
# Arrival Cancellations                            0.374021
# Departure Diversions                             0.414007
# Arrival Diversions                               0.495312
# Key                                              0.073874
# LocID                                            0.156361
# ALIAS                                            0.229292
# Facility Type                                         NaN
# FAA REGION                                       0.069103
# COUNTY                                          -0.025704
# CITY                                             0.015657
# STATE                                            0.121385
# AP Type                                         -0.233684
# Latitude                                        -0.063294
# Longitude                                        0.006927
# Boundary Data Available                          0.052364
# airport                                         -0.189063
# year                                             0.152433
# departures for metric computation                0.824844
# arrivals for metric computation                  0.824782
# percent on-time gate departures                  0.136926
# percent on-time airport departures              -0.108295
# percent on-time gate arrivals                    0.226928
# average_gate_departure_delay                    -0.082909
# average_taxi_out_time                            0.571928
# average taxi out delay                           0.635614
# average airport departure delay                  0.146207
# average airborne delay                           0.234797
# average taxi in delay                            1.000000
# average block delay                              0.229558
# average gate arrival delay                      -0.064446
#
#                                     average block delay  \
# Year                                                NaN
# Departure Cancellations                       -0.008727
# Arrival Cancellations                         -0.006803
# Departure Diversions                           0.118190
# Arrival Diversions                             0.131565
# Key                                            0.017673
# LocID                                         -0.133575
# ALIAS                                          0.113839
# Facility Type                                       NaN
# FAA REGION                                     0.321391
# COUNTY                                        -0.013116
# CITY                                          -0.236551
# STATE                                          0.101802
# AP Type                                        0.001012
# Latitude                                       0.127444
# Longitude                                     -0.390018
# Boundary Data Available                        0.056083
# airport                                        0.190632
# year                                          -0.257872
# departures for metric computation              0.202558
# arrivals for metric computation                0.200918
# percent on-time gate departures               -0.317596
# percent on-time airport departures            -0.346433
# percent on-time gate arrivals                 -0.359406
# average_gate_departure_delay                   0.321592
# average_taxi_out_time                          0.241858
# average taxi out delay                         0.108179
# average airport departure delay                0.340110
# average airborne delay                         0.463519
# average taxi in delay                          0.229558
# average block delay                            1.000000
# average gate arrival delay                     0.421186
#
#                                     average gate arrival delay
# Year                                                       NaN
# Departure Cancellations                               0.002457
# Arrival Cancellations                                 0.006280
# Departure Diversions                                  0.017786
# Arrival Diversions                                    0.036263
# Key                                                   0.092495
# LocID                                                -0.021481
# ALIAS                                                 0.014193
# Facility Type                                              NaN
# FAA REGION                                           -0.051720
# COUNTY                                               -0.108231
# CITY                                                 -0.185172
# STATE                                                 0.158519
# AP Type                                               0.017557
# Latitude                                             -0.017369
# Longitude                                             0.038363
# Boundary Data Available                              -0.002633
# airport                                              -0.066136
# year                                                  0.159727
# departures for metric computation                    -0.136817
# arrivals for metric computation                      -0.135330
# percent on-time gate departures                      -0.811366
# percent on-time airport departures                   -0.777052
# percent on-time gate arrivals                        -0.950755
# average_gate_departure_delay                          0.892105
# average_taxi_out_time                                 0.079991
# average taxi out delay                               -0.014721
# average airport departure delay                       0.839480
# average airborne delay                                0.296419
# average taxi in delay                                -0.064446
# average block delay                                   0.421186
# average gate arrival delay                            1.000000
#
# [32 rows x 32 columns]

# %%
# exporting correlation data to csv so that I can better work it in Excel
df_corr = df14.corr()
df_corrdf = pd.DataFrame(df_corr)
df_corrdf
df_corrdf.to_csv('/Users/EKandTower/GA-DSI/projects/projects-weekly/project-07/\
assets/df_corrdf.csv')

# %% [raw]
# very strong correlations exist between many pairs.
#
# will drop features based on correlations and preceived utility.

# %%
dfn2 = pd.DataFrame(df14)

dfn2 = dfn2.drop(['Year','Facility Type','Arrival Cancellations','Departure Diversions','Arrival Diversions',\
                  'Key','LocID','ALIAS','FAA REGION','Boundary Data Available','airport','year',\
                  'arrivals for metric computation','percent on-time gate departures',\
                  'percent on-time airport departures','percent on-time gate arrivals',\
                  'average_gate_departure_delay','average_taxi_out_time','average gate arrival delay'], axis=1)

dfn2.head()
# Out:
#    AP_NAME  Departure Cancellations  COUNTY  CITY  STATE  AP Type   Latitude  \
# 10     ABQ                    315.0       0   546     11        0  18.439295
# 21     ANC                    111.0     235   328      6        1  21.152886
# 32     ATL                   5977.0      98   415      4        1  25.778333
# 43     AUS                    484.0      57   500     13        1  26.166194
# 54     BDL                    467.0     384   502     13        1  26.562843
#
#      Longitude  departures for metric computation  average taxi out delay  \
# 10  -66.002004                              33292                    2.41
# 21 -157.096256                              71099                    1.33
# 32  -80.170278                             428954                    4.92
# 43  -97.345889                              60588                    2.06
# 54  -97.437759                              39279                    2.58
#
#     average airport departure delay  average airborne delay  \
# 10                            15.99                    1.73
# 21                            12.34                    4.09
# 32                            15.93                    2.74
# 43                            15.59                    2.25
# 54                            14.39                    2.34
#
#     average taxi in delay  average block delay
# 10                   1.02                 2.40
# 21                   0.54                 4.57
# 32                   2.77                 3.21
# 43                   1.08                 2.88
# 54                   0.95                 2.64

# %%
sns.pairplot(dfn2, kind="scatter", size=15)

# %% [markdown]
# #### 4.3 What is the value of understanding correlations before PCA?

# %% [markdown]
# Answer: you should eliminate one side of highly correlated pairs

# %% [markdown]
# #### 4.4 Validate your findings using statistical analysis

# %% [markdown]
# #### 4.5 How can you improve your overall analysis?

# %% [markdown]
# Answer:

# %% [markdown]
# ### Part 5: Perform a PCA

# %% [raw]
# target doesn't have to bde airport, it can be a feature.
#
# I can see what features contribute most to average taxi delay'
#
# need 2 targets, one airport, the other the feature(s) that is/are the primary causes.

# %% [markdown]
# #### 5.1 Conduct the PCA

# %%
df14 = pd.DataFrame(df)
# df14.pop('ap_type')
# df14.pop('region')
# df14.pop('LocID')

# %%
df14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 805 entries, 0 to 804
# Data columns (total 33 columns):
# AP_NAME                               805 non-null int64
# Year                                  805 non-null float64
# Departure Cancellations               805 non-null float64
# Arrival Cancellations                 805 non-null float64
# Departure Diversions                  805 non-null float64
# Arrival Diversions                    805 non-null float64
# Key                                   805 non-null float64
# LocID                                 805 non-null int64
# ALIAS                                 805 non-null int64
# Fac_Type                              805 non-null int64
# FAA REGION                            805 non-null int64
# COUNTY                                805 non-null int64
# CITY                                  805 non-null int64
# STATE                                 805 non-null int64
# AP_Type                               805 non-null int64
# Latitude                              805 non-null float64
# Longitude                             805 non-null float64
# Boundary Data Available               805 non-null int64
# airport                               805 non-null float64
# year                                  805 non-null int64
# departures for metric computation     805 non-null int64
# arrivals for metric computation       805 non-null int64
# percent on-time gate departures       805 non-null float64
# percent on-time airport departures    805 non-null float64
# percent on-time gate arrivals         805 non-null float64
# average_gate_departure_delay          805 non-null float64
# average_taxi_out_time                 805 non-null float64
# average taxi out delay                805 non-null float64
# average airport departure delay       805 non-null float64
# average airborne delay                805 non-null float64
# average taxi in delay                 805 non-null float64
# average block delay                   805 non-null float64
# average gate arrival delay            805 non-null float64
# dtypes: float64(20), int64(13)
# memory usage: 207.6 KB

# %%
df14.pop
# Out:
# <bound method DataFrame.pop of      AP_NAME    Year  Departure Cancellations  Arrival Cancellations  \
# 0          0  2004.0                    242.0                  235.0
# 1          0  2005.0                    221.0                  190.0
# 2          0  2006.0                    392.0                  329.0
# 3          0  2007.0                    366.0                  304.0
# 4          0  2008.0                    333.0                  300.0
# 5          0  2009.0                    192.0                  162.0
# 6          0  2010.0                    222.0                  177.0
# 7          0  2011.0                    345.0                  294.0
# 8          0  2012.0                    237.0                  181.0
# 9          0  2013.0                    232.0                  212.0
# 10         0  2014.0                    315.0                  274.0
# 11         1  2004.0                    473.0                  532.0
# 12         1  2005.0                    424.0                  484.0
# 13         1  2006.0                    367.0                  436.0
# 14         1  2007.0                    359.0                  423.0
# 15         1  2008.0                    268.0                  355.0
# 16         1  2009.0                    354.0                  421.0
# 17         1  2010.0                    149.0                  204.0
# 18         1  2011.0                    191.0                  265.0
# 19         1  2012.0                    216.0                  284.0
# 20         1  2013.0                    141.0                  184.0
# 21         1  2014.0                    111.0                  162.0
# 22         2  2004.0                   7870.0                 8433.0
# 23         2  2005.0                  13837.0                14480.0
# 24         2  2006.0                   6624.0                 7301.0
# 25         2  2007.0                   6796.0                 7790.0
# 26         2  2008.0                   5830.0                 6705.0
# 27         2  2009.0                   5324.0                 6303.0
# 28         2  2010.0                   8198.0                 9279.0
# 29         2  2011.0                   6555.0                 7484.0
# ..       ...     ...                      ...                    ...
# 775       71  2007.0                    120.0                  103.0
# 776       71  2008.0                     53.0                   41.0
# 777       71  2009.0                     29.0                   18.0
# 778       71  2010.0                     67.0                   54.0
# 779       71  2011.0                     42.0                   40.0
# 780       71  2012.0                     14.0                   12.0
# 781       71  2013.0                     27.0                   23.0
# 782       71  2014.0                     17.0                   11.0
# 783       72  2004.0                   1167.0                 1016.0
# 784       72  2005.0                    771.0                  746.0
# 785       72  2006.0                    427.0                  356.0
# 786       72  2007.0                    705.0                  655.0
# 787       72  2008.0                    727.0                  654.0
# 788       72  2009.0                    349.0                  307.0
# 789       72  2010.0                    709.0                  655.0
# 790       72  2011.0                    667.0                  622.0
# 791       72  2012.0                    450.0                  411.0
# 792       72  2013.0                    326.0                  301.0
# 793       72  2014.0                    723.0                  691.0
# 794       73  2004.0                    103.0                   80.0
# 795       73  2005.0                    126.0                  101.0
# 796       73  2006.0                    206.0                  174.0
# 797       73  2007.0                    281.0                  237.0
# 798       73  2008.0                    206.0                  174.0
# 799       73  2009.0                    117.0                  100.0
# 800       73  2010.0                    144.0                  110.0
# 801       73  2011.0                    204.0                  183.0
# 802       73  2012.0                    117.0                  107.0
# 803       73  2013.0                    175.0                  153.0
# 804       73  2014.0                    178.0                  155.0
#
#      Departure Diversions  Arrival Diversions     Key  LocID  ALIAS  Fac_Type  \
# 0                    71.0                46.0  3443.0    687    280         0
# 1                    61.0                33.0  5088.0    799      0         0
# 2                    71.0               124.0  2886.0    635     13         0
# 3                   107.0                45.0  2879.0    769      8         0
# 4                    79.0                42.0  2883.0    798     15         0
# 5                    74.0                26.0  2884.0    655     12         0
# 6                    71.0                50.0  2881.0    556     10         0
# 7                    77.0                61.0  5087.0    800      0         0
# 8                    65.0                60.0  5086.0    325      0         0
# 9                    62.0                46.0  3442.0    686    160         0
# 10                   66.0                37.0  2885.0    677     11         0
# 11                   73.0                30.0  2880.0    246      7         0
# 12                   74.0                31.0  2882.0    675      9         0
# 13                   88.0                50.0  2887.0    296     14         0
# 14                   93.0                54.0   974.0    487    287         0
# 15                   97.0                57.0   979.0    504    342         0
# 16                   84.0                80.0   985.0    586    599         0
# 17                   84.0                32.0   984.0    757    587         0
# 18                   87.0                36.0   980.0    534    355         0
# 19                   78.0                36.0   973.0    464    266         0
# 20                   65.0                40.0   976.0    599    324         0
# 21                   74.0                28.0   982.0    570    421         0
# 22                  737.0               772.0   978.0    541    326         0
# 23                  790.0              1080.0   977.0    497    325         0
# 24                  913.0               787.0   975.0    463    294         0
# 25                  920.0              1045.0   972.0    457    185         0
# 26                  982.0              1072.0   983.0    619    481         0
# 27                 1064.0              1116.0   981.0    530    368         0
# 28                  971.0               945.0   811.0    400    334         0
# 29                  903.0               812.0   866.0    585    383         0
# ..                    ...                 ...     ...    ...    ...       ...
# 775                  19.0                21.0  2945.0    188    541         0
# 776                  13.0                15.0  3156.0    355    179         0
# 777                   7.0                 6.0  3284.0    160    484         0
# 778                   5.0                12.0  3085.0    706      6         0
# 779                   4.0                 5.0  5164.0    414      0         0
# 780                   3.0                 1.0  5250.0    425      0         0
# 781                   7.0                 6.0   613.0    600    445         0
# 782                   3.0                11.0   330.0    738    581         0
# 783                 154.0               139.0   408.0    392    508         0
# 784                 212.0               103.0   971.0    177    623         0
# 785                 197.0               189.0   917.0    186    257         0
# 786                 186.0               121.0   377.0    254    381         0
# 787                 194.0               182.0  3215.0     63    307         0
# 788                 201.0               102.0  5185.0     64      0         0
# 789                 157.0               140.0  2388.0    739    577         0
# 790                 176.0               137.0   647.0    661    510         0
# 791                 131.0               132.0  3153.0    539    171         0
# 792                 152.0               118.0  2898.0    291     47         0
# 793                 183.0               163.0   498.0    506     71         0
# 794                  50.0                22.0  4847.0     45      0         0
# 795                  36.0                26.0   428.0    312    110         0
# 796                  63.0                46.0  5135.0    202      0         0
# 797                  65.0                22.0  4098.0    382      0         0
# 798                  59.0                16.0  5192.0     16      0         0
# 799                  38.0                28.0   257.0     71     38         0
# 800                  42.0                35.0  3136.0     79    137         0
# 801                  43.0                28.0   472.0    616    548         0
# 802                  38.0                29.0  5097.0    163      0         0
# 803                  62.0                18.0  2381.0    650    502         0
# 804                  55.0                39.0  4669.0    236      0         0
#
#                 ...              percent on-time airport departures  \
# 0               ...                                          0.7809
# 1               ...                                          0.7922
# 2               ...                                          0.7756
# 3               ...                                          0.7704
# 4               ...                                          0.7844
# 5               ...                                          0.8147
# 6               ...                                          0.7907
# 7               ...                                          0.7758
# 8               ...                                          0.7940
# 9               ...                                          0.7402
# 10              ...                                          0.7148
# 11              ...                                          0.6770
# 12              ...                                          0.7061
# 13              ...                                          0.7455
# 14              ...                                          0.7457
# 15              ...                                          0.7698
# 16              ...                                          0.7952
# 17              ...                                          0.7760
# 18              ...                                          0.8050
# 19              ...                                          0.8235
# 20              ...                                          0.8228
# 21              ...                                          0.8074
# 22              ...                                          0.5757
# 23              ...                                          0.6216
# 24              ...                                          0.5324
# 25              ...                                          0.5713
# 26              ...                                          0.6071
# 27              ...                                          0.5900
# 28              ...                                          0.6405
# 29              ...                                          0.6730
# ..              ...                                             ...
# 775             ...                                          0.8126
# 776             ...                                          0.7915
# 777             ...                                          0.7746
# 778             ...                                          0.7371
# 779             ...                                          0.7515
# 780             ...                                          0.7976
# 781             ...                                          0.7635
# 782             ...                                          0.7623
# 783             ...                                          0.7851
# 784             ...                                          0.7416
# 785             ...                                          0.7150
# 786             ...                                          0.6544
# 787             ...                                          0.6776
# 788             ...                                          0.6542
# 789             ...                                          0.6583
# 790             ...                                          0.7155
# 791             ...                                          0.6687
# 792             ...                                          0.7192
# 793             ...                                          0.6918
# 794             ...                                          0.7467
# 795             ...                                          0.6987
# 796             ...                                          0.6955
# 797             ...                                          0.3104
# 798             ...                                          0.2885
# 799             ...                                          0.3151
# 800             ...                                          0.2951
# 801             ...                                          0.2774
# 802             ...                                          0.2457
# 803             ...                                          0.2767
# 804             ...                                          0.3170
#
#      percent on-time gate arrivals  average_gate_departure_delay  \
# 0                           0.7921                         10.38
# 1                           0.8001                          9.60
# 2                           0.7746                         10.84
# 3                           0.7647                         11.29
# 4                           0.7875                         10.79
# 5                           0.8224                          9.24
# 6                           0.8047                         10.25
# 7                           0.8022                         10.81
# 8                           0.8177                         10.55
# 9                           0.7554                         12.56
# 10                          0.7320                         14.30
# 11                          0.6502                         21.45
# 12                          0.6955                         18.36
# 13                          0.7110                         15.56
# 14                          0.7196                         15.69
# 15                          0.7573                         13.45
# 16                          0.8264                         15.10
# 17                          0.8045                         17.77
# 18                          0.8292                         14.56
# 19                          0.8521                         10.01
# 20                          0.8631                          9.18
# 21                          0.8600                         11.33
# 22                          0.7370                         13.59
# 23                          0.7337                         15.50
# 24                          0.7205                         16.20
# 25                          0.7446                         16.77
# 26                          0.7559                         13.86
# 27                          0.7335                         13.20
# 28                          0.7956                         12.82
# 29                          0.8068                         12.20
# ..                             ...                           ...
# 775                         0.8263                         10.00
# 776                         0.8193                         10.41
# 777                         0.8061                         11.71
# 778                         0.7604                         14.26
# 779                         0.7758                         13.73
# 780                         0.8168                         10.74
# 781                         0.7952                         12.16
# 782                         0.7897                         12.52
# 783                         0.8160                         11.03
# 784                         0.7805                         13.24
# 785                         0.7506                         15.01
# 786                         0.6525                         16.63
# 787                         0.6547                         17.30
# 788                         0.6141                         18.78
# 789                         0.6277                         17.40
# 790                         0.6920                         16.07
# 791                         0.6476                         16.71
# 792                         0.6559                         14.95
# 793                         0.6275                         17.80
# 794                         0.6955                         14.40
# 795                         0.6483                         14.62
# 796                         0.6843                         16.78
# 797                         0.3800                         38.41
# 798                         0.3495                         37.84
# 799                         0.3598                         37.94
# 800                         0.3583                         39.86
# 801                         0.3611                         38.56
# 802                         0.3979                         40.80
# 803                         0.3791                         38.17
# 804                         0.3982                         35.25
#
#      average_taxi_out_time  average taxi out delay  \
# 0                     9.89                    2.43
# 1                     9.79                    2.29
# 2                     9.89                    2.16
# 3                    10.34                    2.40
# 4                    10.41                    2.41
# 5                     9.88                    1.89
# 6                     9.95                    2.05
# 7                    10.50                    2.51
# 8                    10.27                    2.32
# 9                    10.77                    2.64
# 10                   10.64                    2.41
# 11                   12.41                    2.92
# 12                   12.19                    2.78
# 13                   12.84                    2.54
# 14                   13.19                    2.29
# 15                   13.44                    1.86
# 16                   12.49                    1.55
# 17                   11.97                    1.79
# 18                   11.89                    1.66
# 19                   11.71                    1.52
# 20                   12.03                    1.51
# 21                   11.33                    1.33
# 22                   20.45                    8.73
# 23                   18.52                    7.26
# 24                   20.38                    9.63
# 25                   19.67                    8.28
# 26                   20.60                    9.01
# 27                   21.84                    9.73
# 28                   21.26                    8.61
# 29                   20.33                    7.52
# ..                     ...                     ...
# 775                  11.42                    1.67
# 776                  11.69                    2.68
# 777                  11.49                    2.06
# 778                  11.45                    2.15
# 779                  11.40                    2.19
# 780                  11.00                    1.76
# 781                  10.84                    1.89
# 782                  10.74                    1.95
# 783                  10.61                    1.89
# 784                  10.61                    2.04
# 785                  10.74                    2.10
# 786                  12.91                    3.42
# 787                  12.10                    2.38
# 788                  11.91                    1.92
# 789                  13.76                    3.84
# 790                  13.37                    2.42
# 791                  14.65                    3.02
# 792                  14.09                    2.46
# 793                  13.17                    1.30
# 794                  12.31                    0.83
# 795                  14.03                    2.70
# 796                  12.42                    0.65
# 797                   9.11                    0.00
# 798                   9.44                    0.54
# 799                  10.33                    0.05
# 800                  11.05                    0.08
# 801                  11.20                    0.14
# 802                  11.15                    0.10
# 803                  11.20                    0.14
# 804                  11.16                    0.11
#
#      average airport departure delay  average airborne delay  \
# 0                              12.10                    2.46
# 1                              11.20                    2.26
# 2                              12.33                    2.12
# 3                              12.95                    2.19
# 4                              12.32                    1.82
# 5                              10.45                    1.74
# 6                              11.58                    1.66
# 7                              12.57                    1.58
# 8                              12.11                    1.41
# 9                              14.28                    1.60
# 10                             15.99                    1.73
# 11                             23.05                    4.03
# 12                             19.97                    3.65
# 13                             17.07                    4.29
# 14                             17.52                    5.13
# 15                             14.72                    5.13
# 16                             15.88                    3.85
# 17                             18.83                    3.75
# 18                             15.60                    3.92
# 19                             11.00                    3.86
# 20                             10.09                    3.40
# 21                             12.34                    4.09
# 22                             21.36                    5.00
# 23                             21.80                    4.24
# 24                             24.85                    3.71
# 25                             24.18                    3.88
# 26                             21.59                    4.11
# 27                             21.48                    3.31
# 28                             19.90                    2.66
# 29                             18.25                    2.41
# ..                               ...                     ...
# 775                            10.94                    3.93
# 776                            12.15                    3.60
# 777                            13.03                    3.03
# 778                            15.77                    3.66
# 779                            15.22                    3.95
# 780                            11.93                    3.29
# 781                            13.33                    2.78
# 782                            13.86                    2.41
# 783                            12.41                    2.03
# 784                            14.81                    1.59
# 785                            16.62                    1.78
# 786                            18.90                    3.63
# 787                            18.61                    3.30
# 788                            19.73                    3.38
# 789                            20.49                    2.49
# 790                            17.78                    2.71
# 791                            19.20                    2.84
# 792                            16.71                    2.89
# 793                            18.35                    2.91
# 794                            14.59                    2.72
# 795                            16.73                    2.49
# 796                            17.24                    2.83
# 797                            36.89                    6.28
# 798                            38.30                    6.23
# 799                            37.47                    5.67
# 800                            39.90                    5.90
# 801                            38.69                    5.69
# 802                            40.87                    5.22
# 803                            38.31                    5.26
# 804                            35.40                    5.39
#
#      average taxi in delay  average block delay  average gate arrival delay
# 0                     0.83                 2.55                       10.87
# 1                     0.89                 2.34                       10.24
# 2                     0.84                 2.66                       11.82
# 3                     1.29                 3.06                       12.71
# 4                     1.03                 2.79                       11.48
# 5                     0.92                 1.98                        9.27
# 6                     0.95                 1.90                       10.23
# 7                     0.84                 1.87                       10.63
# 8                     0.98                 1.80                        9.73
# 9                     0.92                 2.35                       12.76
# 10                    1.02                 2.40                       14.72
# 11                    1.08                 5.93                       22.62
# 12                    1.01                 4.96                       19.35
# 13                    0.72                 5.83                       17.71
# 14                    0.39                 5.87                       18.09
# 15                    0.63                 5.93                       15.89
# 16                    0.31                 4.19                       15.95
# 17                    0.37                 3.91                       20.28
# 18                    0.55                 4.01                       13.93
# 19                    0.34                 3.75                        9.33
# 20                    0.47                 3.82                        8.46
# 21                    0.54                 4.57                       10.82
# 22                    2.79                 4.69                       15.31
# 23                    2.72                 4.62                       17.23
# 24                    4.13                 4.72                       16.95
# 25                    4.17                 4.43                       16.09
# 26                    4.07                 5.09                       15.71
# 27                    4.75                 5.70                       16.54
# 28                    4.32                 3.67                       14.16
# 29                    4.00                 3.54                       12.56
# ..                     ...                  ...                         ...
# 775                   0.53                 2.06                        9.76
# 776                   1.31                 2.09                       10.72
# 777                   0.79                 2.25                       11.43
# 778                   1.18                 2.69                       14.37
# 779                   1.15                 2.92                       13.86
# 780                   0.78                 2.25                       10.54
# 781                   1.28                 2.50                       11.60
# 782                   1.38                 2.79                       12.15
# 783                   1.27                 2.30                       10.68
# 784                   0.89                 2.36                       12.62
# 785                   0.99                 2.75                       14.64
# 786                   0.45                 4.34                       18.67
# 787                   0.74                 4.75                       17.92
# 788                   0.67                 5.72                       21.09
# 789                   1.61                 6.14                       20.78
# 790                   0.68                 4.27                       17.68
# 791                   0.75                 4.93                       19.37
# 792                   0.51                 4.91                       19.69
# 793                   0.84                 4.34                       20.71
# 794                   0.34                 3.78                       16.55
# 795                   0.82                 5.50                       18.87
# 796                   0.23                 4.73                       17.14
# 797                   0.00                 6.09                       31.14
# 798                   0.26                 7.44                       34.28
# 799                   0.00                 6.05                       32.70
# 800                   0.01                 6.58                       33.33
# 801                   0.00                 6.21                       33.41
# 802                   0.00                 5.12                       31.05
# 803                   0.00                 5.15                       31.97
# 804                   0.00                 5.05                       30.94
#
# [805 rows x 33 columns]>

# %%
# change y to something

# %%
x = df14.ix[:,1:].values
y = dfn.ix[:,0].values

# %%
xStand = StandardScaler().fit_transform(x)

# %%
covMat = np.cov(xStand.T)
eigenValues, eigenVectors = np.linalg.eig(covMat)

# %%
print(eigenValues)
print(eigenVectors)
# Out:
# [  7.11138192e+00   4.85257108e+00   2.85150212e+00   2.47005052e+00
#    2.07721901e+00   1.80998968e+00   1.70095899e+00   1.30068430e+00
#    9.61398184e-01   9.08673207e-01   8.10593783e-01   7.31844611e-01
#    6.63778256e-01   5.43456142e-01   4.57904765e-01   3.16992882e-01
#    2.94879740e-01   2.49034954e-01   1.98196878e-01   1.57743262e-01
#    1.47384756e-01   1.30532529e-01   1.15926637e-01   7.95135153e-02
#    6.13830015e-02   1.79486145e-02   1.13572869e-02   3.03528147e-03
#    1.68762186e-03   7.83576617e-04   1.50108444e-04   0.00000000e+00]
# [[  3.11625380e-02  -3.78853782e-02  -4.37452913e-02 ...,  -3.25527213e-03
#     2.45955754e-04   0.00000000e+00]
#  [ -1.52823119e-01   2.64742846e-01  -1.63766815e-01 ...,   3.67558997e-02
#     5.24270815e-03   0.00000000e+00]
#  [ -1.54082615e-01   2.66983037e-01  -1.62594470e-01 ...,  -3.89437058e-02
#    -3.35752593e-03   0.00000000e+00]
#  ...,
#  [ -2.22316876e-01   2.49458494e-01   9.84542989e-02 ...,   2.30793951e-03
#     4.03092447e-03   0.00000000e+00]
#  [ -2.72940735e-01  -7.65547480e-02   3.15539279e-02 ...,  -5.62975667e-03
#     1.38637659e-03   0.00000000e+00]
#  [ -2.74578590e-01  -2.67860571e-01  -6.88449290e-03 ...,   1.97392701e-02
#     2.19072681e-03   0.00000000e+00]]

# %%
eigenPairs = [(np.abs(eigenValues[i]), eigenVectors[:,i]) for i in range(len(eigenValues))]
eigenPairs.sort()
eigenPairs.reverse()
for i in eigenPairs:
    print(i[0])
# Out:
# 7.1113819202
# 4.85257107685
# 2.85150212071
# 2.47005051599
# 2.07721901316
# 1.80998967925
# 1.70095899347
# 1.30068430177
# 0.961398184175
# 0.908673207013
# 0.810593783171
# 0.731844610544
# 0.663778256435
# 0.543456141817
# 0.457904764552
# 0.316992882208
# 0.294879739863
# 0.24903495396
# 0.198196877628
# 0.157743262035
# 0.147384755775
# 0.130532529344
# 0.115926637395
# 0.0795135153473
# 0.0613830015128
# 0.017948614503
# 0.0113572868789
# 0.00303528146819
# 0.00168762186279
# 0.000783576617277
# 0.000150108443968
# 0.0

# %%
totalEigen = sum(eigenValues)
varExpl = [(i / totalEigen)*100 for i in sorted(eigenValues, reverse=True)]
cumulvarExpl = np.cumsum(varExpl)

# %%
print(cumulvarExpl)
# Out:
# [  22.91144486   38.54545466   47.73242202   55.69042889   62.38281153
#    68.2142349    73.69438329   77.88492698   80.98235892   83.90992156
#    86.521492     88.87934841   91.01790869   92.76881527   94.24409249
#    95.26537992   96.21542324   97.01776387   97.65631442   98.16453154
#    98.63937563   99.05992523   99.43341759   99.68959417   99.88735788
#    99.94518471   99.98177561   99.99155468   99.99699185   99.99951638
#   100.          100.        ]

# %%
airports_pca = PCA(n_components=3)
airports_pca.fit(xStand)
X = airports_pca.transform(xStand)

airports_pca.components_
# components_.X
# Out:
# array([[  3.11625380e-02,  -1.52823119e-01,  -1.54082615e-01,
#          -1.63135843e-01,  -1.63254892e-01,  -2.01662627e-02,
#           2.27790326e-02,   3.66567648e-02,   0.00000000e+00,
#          -2.52450507e-02,   2.27023559e-02,   4.02310698e-02,
#          -8.99441696e-03,   6.07736818e-04,   3.02858369e-02,
#           4.65397122e-02,   2.53775619e-02,   5.33587819e-02,
#           6.58183723e-02,  -2.16953469e-01,  -2.16476075e-01,
#           2.28643053e-01,   3.26428698e-01,   2.26437894e-01,
#          -2.61914846e-01,  -2.64026141e-01,  -2.58605545e-01,
#          -3.36423775e-01,  -2.46817521e-01,  -2.22316876e-01,
#          -2.72940735e-01,  -2.74578590e-01],
#        [ -3.78853782e-02,   2.64742846e-01,   2.66983037e-01,
#           2.75816087e-01,   2.71647942e-01,   1.13363635e-02,
#           3.54699589e-02,   2.14602545e-02,   0.00000000e+00,
#           3.28159681e-03,  -3.38032269e-02,   1.59348255e-02,
#           2.36849983e-02,  -3.99746807e-03,  -9.64169653e-02,
#          -3.91000746e-02,   5.02610131e-03,  -1.23657921e-01,
#           3.44745699e-05,   2.84707329e-01,   2.84701955e-01,
#           2.96933763e-01,   1.81827416e-01,   3.23938667e-01,
#          -2.76940608e-01,   1.39892883e-01,   1.48790129e-01,
#          -1.68081904e-01,  -5.07897162e-02,   2.49458494e-01,
#          -7.65547480e-02,  -2.67860571e-01],
#        [  4.37452913e-02,   1.63766815e-01,   1.62594470e-01,
#           1.23062552e-01,   1.42119839e-01,   4.95978907e-01,
#          -1.01531594e-01,  -3.37488301e-01,   0.00000000e+00,
#           2.94103393e-01,   3.21858435e-02,  -7.84446988e-02,
#           3.65010638e-01,   1.15617580e-01,   7.69019692e-02,
#          -2.14042901e-01,  -4.00824873e-01,   9.36447107e-02,
#           3.75369470e-02,  -1.00123145e-01,  -9.96871680e-02,
#          -5.49924107e-02,   1.74163965e-02,  -4.00945099e-02,
#           3.78178658e-02,  -1.28204435e-01,  -1.28374915e-01,
#          -2.40007413e-02,  -7.66506267e-02,  -9.84542989e-02,
#          -3.15539279e-02,   6.88449290e-03]])

# %%
from matplotlib import pyplot as plt
with plt.style.context('seaborn-whitegrid'):
    plt.figure(figsize=(6, 4))

    plt.bar(range(len(cumulvarExpl)), varExpl, alpha=0.5, align='center',
            label='individual explained variance')
    plt.step(range(len(cumulvarExpl)), cumulvarExpl, where='mid',
             label='cumulative explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()

# %% [markdown]
# ### Part 6: Additional Analysis
# Include any other models you'd like to run here. These can include regressions, classifications, or clusters.

# %% [markdown]
# ### Part 7: Write an analysis plan of your findings

# %% [markdown]
# Create a writeup on the interpretation of findings including an executive summary with conclusions and next steps. Put it on your blog, and include the link here.

# %% [markdown]
# Which operational features are most correlated with delays?

# %% [markdown]
# What should the airport's next steps be?

# %% [markdown]
# ### Bonus: Copy your Database to AWS

# %% [markdown]
# Make sure to properly document all of the features of your dataset

# %% [markdown]
# ### Bonus: Create a 3-Dimensional Plot of your new dataset with PCA applied
