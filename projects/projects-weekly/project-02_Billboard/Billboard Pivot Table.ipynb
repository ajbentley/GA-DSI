# %%
import numpy as np
import scipy as sp
import pandas as pd
from datetime import *

df = pd.read_csv('/Users/EKandTower/Dropbox/GA-DSI/all_billboard_data_csv copy.csv')

pd.pivot_table(df, index=['chart year'], values=['overall weeks on chart', \
                                                 'entry position'], aggfunc=[np.mean, np.max, np.min])



# woc_yr = df.loc[['1989','1990','2008'],['weeks on chart','chart year']]

# df.head()


# df.loc[df['column_name'] == some_value]

# pd.pivot_table(df, index=[df.loc[df['chart year'] == 1997], values=['overall weeks on chart', \
#                                                  'entry position'], aggfunc=[np.mean, np.max, np.min])


# df.loc[df['column_name'].isin(some_values)]




# pd.pivot_table(df, index=[df.loc[df['chart year'].isin('1997','1998')]], \
#                           values=['overall weeks on chart','entry position'], aggfunc=[np.mean, np.max, np.min])
# Out:
#                      mean                                  amax  \
#            entry position overall weeks on chart entry position
# chart year
# 1940             6.787500               8.654167           10.0
# 1941             7.380769               8.973077           10.0
# 1942             7.644231              10.492308           10.0
# 1943             8.109615              12.740385           10.0
# 1944             6.896679              10.636531           17.0
# 1945             7.058491               9.356604           10.0
# 1946             7.430769              10.230769           10.0
# 1947             7.650995               9.589512           15.0
# 1948            13.536559              13.783871           20.0
# 1949            15.371154              13.091346           20.0
# 1950            14.589423              12.078846           20.0
# 1951            15.875000              15.957692           20.0
# ...
