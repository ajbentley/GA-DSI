# %%
import numpy as np
import scipy as sp
import pandas as pd
from datetime import *

startDate = datetime(1997,1,1)
endDate = datetime(2000,12,31)

syr = 1984
eyr = 1986

loopRange = range(syr, eyr)

def datesWithinRange(x, start, end):
    a = []
    for ind,i in enumerate(x):
        newDate = datetime.strptime(i, '%m/%d/%Y')
        if newDate > start and newDate < end:
            a.append(ind)
    return a

df = pd.read_csv('/Users/EKandTower/Dropbox/GA-DSI/all_billboard_data_csv.csv')

lists = []
for i in loopRange:
    startDate = datetime(i,1,1)
    endDate = datetime(i,12,31)
    lists.append(datesWithinRange(df['Chart week'], startDate, endDate))

#df['Chart week']
#result = datesWithinRange(df['Chart week'], startDate, endDate)
#result

#df.ix(result[0])
#df[result[0]:result[len(result)-1]]
#lists
#df[lists[0][0]:lists[0][len(lists[0])-1]]
np.average(df[lists[0][0]:lists[0][len(lists[0])-1]]['overall peak'])

#for l in lists:
#    df[l[0]:l[len(l)-1]]['Chart week']

#vars(df['Chart week'])
#vars(startDate)

#type(df[['Chart week']])

#df.head()

#dir(df['Chart week'])
# Out:
# 28.126755145220233

# %%
import numpy as np
import scipy as sp
import pandas as pd
from datetime import *

startDate = datetime(1997,1,1)
endDate = datetime(2000,12,31)

syr = 1997
eyr = 2000

loopRange = range(syr, eyr)

def datesWithinRange(x, start, end):
    a = []
    for ind,i in enumerate(x):
        newDate = datetime.strptime(i, '%m/%d/%Y')
        if newDate > start and newDate < end:
            a.append(ind)
    return a

df = pd.read_csv('/Users/EKandTower/Dropbox/GA-DSI/all_billboard_data_csv.csv')

lists = []
for i in loopRange:
    startDate = datetime(i,1,1)
    endDate = datetime(i,12,31)
    lists.append(datesWithinRange(df['Chart week'], startDate, endDate))

#df['Chart week']
#result = datesWithinRange(df['Chart week'], startDate, endDate)
#result

#df.ix(result[0])
#df[result[0]:result[len(result)-1]]
#lists
#df[lists[0][0]:lists[0][len(lists[0])-1]]

np.average(df[lists[0][0]:lists[0][len(lists[0])-1]]['overall peak'])

#for l in lists:
#    df[l[0]:l[len(l)-1]]['Chart week']

#vars(df['Chart week'])
#vars(startDate)

#type(df[['Chart week']])

#df.head()

#dir(df['Chart week'])

# %%
lists
# Out:
# [[157500,
#   157501,
#   157502,
#   157503,
#   157504,
#   157505,
#   157506,
#   157507,
#   157508,
#   157509,
#   157510,
#   157511,
#   157512,
#   157513,
#   157514,
#   157515,
#   157516,
#   157517,
#   157518,
#   157519,
#   157520,
#   157521,
#   157522,
#   157523,
#   157524,
#   157525,
#   157526,
#   157527,
#   157528,
#   157529,
#   157530,
#   157531,
#   157532,
#   157533,
#   157534,
#   157535,
#   157536,
#   157537,
#   157538,
#   157539,
#   157540,
#   157541,
#   157542,
#   157543,
#   157544,
#   157545,
#   157546,
#   157547,
#   157548,
#   157549,
#   157550,
#   157551,
#   157552,
#   157553,
#   157554,
#   157555,
#   157556,
#   157557,
#   157558,
#   157559,
#   157560,
#   157561,
#   157562,
#   157563,
#   157564,
#   157565,
#   157566,
#   157567,
#   157568,
#   157569,
#   157570,
#   157571,
#   157572,
#   157573,
#   157574,
#   157575,
#   157576,
#   157577,
#   157578,
#   157579,
#   157580,
#   157581,
#   157582,
# ...
