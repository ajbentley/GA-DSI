# %%
import pandas as pd
import numpy as np

# %%
dfc=pd.read_csv("~/GA-DSI/curriculum/week-03/5.1-regression-challenge/datasets/challenge-dataset.csv")

# %%
dfc.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7          96
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
#dfr['world_rank'] = dfr['world_rank'].apply(change_wr)
                        
                        
dfc['country'].unique()
# Out:
# array(['United States of America', 'United Kingdom', 'Switzerland',
#        'Canada', 'Hong Kong', 'Japan', 'South Korea', 'Singapore',
#        'Australia', 'China', 'France', 'Sweden', 'Germany',
#        'Republic of Ireland', 'Finland', 'Taiwan', 'South Africa',
#        'Turkey', 'Netherlands', 'Belgium', 'Denmark', 'Norway', 'Spain',
#        'New Zealand', 'Egypt', 'Austria', 'Israel', 'Brazil', 'Italy',
#        'Russian Federation', 'Greece', 'Iceland', 'Czech Republic',
#        'India', 'Poland', 'Iran', 'Portugal', 'Thailand', 'Chile',
#        'Estonia', 'Saudi Arabia', 'Mexico', 'Colombia', 'Macau', 'Morocco',
#        'Luxembourg', 'Unisted States of America', 'Cyprus',
#        'Unted Kingdom', 'Uganda', 'Malaysia', 'Lebanon', 'Romania',
#        'Slovenia', 'Pakistan', 'Hungary', 'United Arab Emirates',
#        'Belarus', 'Serbia', 'Slovakia', 'Bangladesh', 'Ghana', 'Nigeria',
#        'Indonesia', 'Jordan', 'Latvia', 'Kenya', 'Argentina', 'Qatar',
# ...

# %%
pd.set_option('display.max_rows', 500)
country_df = dfc[['year']]
country_df = country_df.drop_duplicates()
country_df = country_df.sort_values(by='year')
country_df = country_df.reset_index(drop=True)
len(country_df)
country_df
# Out:
#    year
# 0  2011
# 1  2012
# 2  2013
# 3  2014
# 4  2015
# 5  2016

# %% [markdown]
# dfc.items()

# %%
pd.set_option('year', 500)
country_df = dfc[['world_rank']]
# print dfc('world_rank') == '201-225'
country_df = country_df.drop_duplicates()
country_df = country_df.sort_values(by='world_rank')
country_df = country_df.reset_index(drop=True)
len(country_df)
country_df
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-77-eeebdb827a48> in <module>()
# ----> 1 pd.set_option('year', 500)
#       2 year = dfc[['year']]
#       3 # print dfc('world_rank') == '201-225'
#       4 country_df = country_df.drop_duplicates()
#       5 country_df = country_df.sort_values(by='year')
#
# C:\Users\Elizabeth\Anaconda2\lib\site-packages\pandas\core\config.pyc in __call__(self, *args, **kwds)
#     221
#     222     def __call__(self, *args, **kwds):
# --> 223         return self.__func__(*args, **kwds)
#     224
#     225     @property
#
# C:\Users\Elizabeth\Anaconda2\lib\site-packages\pandas\core\config.pyc in _set_option(*args, **kwargs)
#     121         o = _get_registered_option(key)
#     122         if o and o.validator:
# --> 123             o.validator(v)
#     124
#     125         # walk the nested dict
#
# C:\Users\Elizabeth\Anaconda2\lib\site-packages\pandas\core\config.pyc in inner(x)
#     754     def inner(x):
# ...

# %%
dfc[dfc['year']==2016]
# Out:
#      world_rank                                    university_name  \
# 1803          1                 California Institute of Technology
# 1804          2                               University of Oxford
# 1805          3                                Stanford University
# 1806          4                            University of Cambridge
# 1807          5              Massachusetts Institute of Technology
# 1808          6                                 Harvard University
# 1809          7                               Princeton University
# 1810          8                            Imperial College London
# 1811          9  ETH Zurich � Swiss Federal Institute of Techno...
# 1812         10                              University of Chicago
# 1813         11                           Johns Hopkins University
# 1814         12                                    Yale University
# 1815         13                 University of California, Berkeley
# ...

# %%
def clean_f2mr(x):
    if type(x) == type(0.1):
        return x
    else:
       inco
        if len(x) >= 3:
            y = x.split(' : ')
            op = (float(y[0])/float(y[1]))
            return op
        else:
            op = float(x)
            return op
dfc.apply(clean_f2mr,'female_male_ratio')
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-67-6ca68c41b55a> in <module>()
#      11             op = float(x)
#      12             return op
# ---> 13 dfc.apply(clean_f2mr,'female_male_ratio')
#
# C:\Users\Elizabeth\Anaconda2\lib\site-packages\pandas\core\frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4033         applied : Series or DataFrame
#    4034         """
# -> 4035         axis = self._get_axis_number(axis)
#    4036         if kwds or args and not isinstance(func, np.ufunc):
#    4037
#
# C:\Users\Elizabeth\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_axis_number(self, axis)
#     316                 pass
#     317         raise ValueError('No axis named {0} for object type {1}'
# --> 318                          .format(axis, type(self)))
#     319
#     320     def _get_axis_name(self, axis):
#
# ValueError: No axis named female_male_ratio for object type <class 'pandas.core.frame.DataFrame'>

# %%
pd.set_option('display.max_rows', 5000)
country_df = dfc[['international']]
country_df = country_df.drop_duplicates()
#country_df = country_df.sort_values(by='international')
country_df = country_df.reset_index(drop=True)
len(country_df)
dfc.items(type)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-50-6a6cdd8bd079> in <module>()
#       5 country_df = country_df.reset_index(drop=True)
#       6 len(country_df)
# ----> 7 dfc.items(type)
#
# C:\Users\Elizabeth\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2666         if (name in self._internal_names_set or name in self._metadata or
#    2667                 name in self._accessors):
# -> 2668             return object.__getattribute__(self, name)
#    2669         else:
#    2670             if name in self._info_axis:
#
# AttributeError: 'DataFrame' object has no attribute 'items'

# %%
dfc.select_dtypes(include=['object'])
# Out:
#      world_rank                                    university_name  \
# 0             1                                 Harvard University
# 1             2                 California Institute of Technology
# 2             3              Massachusetts Institute of Technology
# 3             4                                Stanford University
# 4             5                               Princeton University
# 5             6                            University of Cambridge
# 6             6                               University of Oxford
# 7             8                 University of California, Berkeley
# 8             9                            Imperial College London
# 9            10                                    Yale University
# 10           11              University of California, Los Angeles
# 11           12                              University of Chicago
# 12           13                           Johns Hopkins University
# ...
