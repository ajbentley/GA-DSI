# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) [Basic SQL]

# %% [markdown]
# ### LEARNING OBJECTIVES
# *After this lesson, you will be able to:*

# %% [markdown]
# connect to a local or remote relational database
# add and remove data, create new tables, alter table schemas
# perform simple queries using SQL language

# %% [markdown]
# ### Introduction (5 mins)

# %% [markdown]
# ### Structured
# ### Query
# ### Language

# %% [markdown]
# SQL is a Relational Database Management System (RDBMS) language with many flavors including
#
# PostreSQL
# mySQL
# SQLite
# MSSQL
# Sybase
#
# What's the difference?
#
# Not much.

# %%
from IPython.display import Image
Image("/Users/ajbentley/GA-DSI-ajb/curriculum/week-11/4.4-peer-teaching/sandwich-map.jpg")

# %% [markdown]
# ![Image](http://www.gepsoft.com/tutorials/imagesLRAP/LogisticRegressionWindowLogisticFitChart6.png)
#
# ![Image](http://ww![Image](http://www.gepsoft.com/tutorials/imagesLRAP/LogisticRegressionWindowLogisticFitChart6.png)w.gepsoft.com/tutorials/imagesLRAP/LogisticRegressionWindowLogisticFitChart6.png)

# %% [markdown]
# Every deployment has slightly different syntax. Think of Python 2.7 versus Python 3.

# %% [markdown]
# Mirrors many functions of Pandas:
# - Create databases and data tables
# - Retrieve data from a database
# - Add or remove data
# - Describe data
# - Manipulate data
# - Perform functions on data

# %% [markdown]
# SQL Databases are usually large / remote.
#
# Database  <--->  Server  <--->   User

# %%
Image("/Users/ajbentley/GA-DSI-ajb/curriculum/week-11/4.4-peer-teaching/bz-panel-12-10-11-Venus-Fly-Trap-WAYNO.jpg")

# %% [markdown]
# How is SQL different than Pandas?
#
# Buffet versus Menu
#
# Pandas you collect all data, then select what you want.
#
# SQL user selects data desired from lists of available.

# %%
Image("/Users/ajbentley/GA-DSI-ajb/curriculum/week-11/4.4-peer-teaching/filemaking-09.png")

# %% [markdown]
# ### SQL Query   ~~   Pandas Code
#
# CREATE TABLE  ~~  pd.DataFrame()
# SELECT  ~~  creating a new DF using only columns from a previous DF
# FROM  ~~  the DF from which you'd be creating a new DF
# WHERE  ~~  example: (dfn.loc[df['Year'] == 2014])
# HAVING  ~~  similar
# GROUPBY  ~~  GROUPBY
# ORDER_BY  ~~  sort_values

# %%
Image("/Users/ajbentley/GA-DSI-ajb/curriculum/week-11/4.4-peer-teaching/SQL3.png")

# %% [markdown]
# ### Other SQL Terms to Know
#
# Key  ~~  Index  (Key is a column of numerical identifiers for a record / row. Should always end in 'id')
# Field  ~~  Column
# NULL  ~~  NaN
#
#
# Primary Key - The key for the database - MUST BE UNIQUE
# Foreign Key - The key in another database that is being referenced

# %% [markdown]
# download navicat
#
# https://www.navicat.com/download

# %% [markdown]
# open postgres
#
# ### Elephant up?

# %%
Image("/Users/ajbentley/GA-DSI-ajb/curriculum/week-11/4.4-peer-teaching/treed_elephant.jpg")

# %% [markdown]
# open Navicat

# %% [markdown]
# ### Guided practice (10 mins)

# %% [markdown]
# ### Independent practice (5 mins)
