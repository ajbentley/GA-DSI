# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime, date, timedelta
from IPython.display import HTML
from matplotlib import cm as cm
from mpl_toolkits.mplot3d import Axes3D
from pandas.io import sql
from sklearn import metrics
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sqlalchemy import create_engine
import csv
import numpy as np
import pandas as pd 
import patsy
import plotly.graph_objs as go
import plotly.plotly as py
from plotly.tools import FigureFactory as FF
from plotly.graph_objs import graph_objs
import psycopg2 as psy
import scipy
import seaborn as sns
import sklearn
py.sign_in('ajbentley', 'zjfu2vasav')

# %%
# Here's an example of loading the CSV using Pandas's built-in HDF5 support:
import pandas as pd

with pd.HDFStore("/Users/ajbentley/Downloads/train.h5", "r") as train:
    # Note that the "train" dataframe is the only dataframe in the file
    df = train.get("train")

# %%
df.head()
# Out:
#    id  timestamp  derived_0  derived_1  derived_2  derived_3  derived_4  \
# 0  10          0   0.370326  -0.006316   0.222831  -0.213030   0.729277
# 1  11          0   0.014765  -0.038064  -0.017425   0.320652  -0.034134
# 2  12          0  -0.010622  -0.050577   3.379575  -0.157525  -0.068550
# 3  25          0        NaN        NaN        NaN        NaN        NaN
# 4  26          0   0.176693  -0.025284  -0.057680   0.015100   0.180894
#
#    fundamental_0  fundamental_1  fundamental_2    ...     technical_36  \
# 0      -0.335633       0.113292       1.621238    ...         0.775208
# 1       0.004413       0.114285      -0.210185    ...         0.025590
# 2      -0.155937       1.219439      -0.764516    ...         0.151881
# 3       0.178495            NaN      -0.007262    ...         1.035936
# 4       0.139445      -0.125687      -0.018707    ...         0.630232
#
#    technical_37  technical_38  technical_39  technical_40  technical_41  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1710756 entries, 0 to 1710755
# Columns: 111 entries, id to y
# dtypes: float32(109), int16(2)
# memory usage: 730.9 MB

# %%
df.info(120)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1710756 entries, 0 to 1710755
# Data columns (total 111 columns):
# id                int16
# timestamp         int16
# derived_0         float32
# derived_1         float32
# derived_2         float32
# derived_3         float32
# derived_4         float32
# fundamental_0     float32
# fundamental_1     float32
# fundamental_2     float32
# fundamental_3     float32
# fundamental_5     float32
# fundamental_6     float32
# fundamental_7     float32
# fundamental_8     float32
# fundamental_9     float32
# fundamental_10    float32
# fundamental_11    float32
# fundamental_12    float32
# fundamental_13    float32
# fundamental_14    float32
# fundamental_15    float32
# fundamental_16    float32
# fundamental_17    float32
# fundamental_18    float32
# fundamental_19    float32
# fundamental_20    float32
# fundamental_21    float32
# fundamental_22    float32
# fundamental_23    float32
# fundamental_24    float32
# ...

# %%
df.set_index('id')
# Out:
#       timestamp  derived_0  derived_1  derived_2  derived_3  derived_4  \
# id
# 10            0   0.370326  -0.006316   0.222831  -0.213030   0.729277
# 11            0   0.014765  -0.038064  -0.017425   0.320652  -0.034134
# 12            0  -0.010622  -0.050577   3.379575  -0.157525  -0.068550
# 25            0        NaN        NaN        NaN        NaN        NaN
# 26            0   0.176693  -0.025284  -0.057680   0.015100   0.180894
# 27            0   0.346856   0.166239  -6.080701  -0.992249  -0.125916
# 31            0   0.072036   0.014931        NaN   0.014063        NaN
# 38            0   0.300062   0.071251  -0.074451  -0.065292  -0.011286
# 39            0  -0.003511  -0.034270   0.082372  -0.023937  -0.025750
# 40            0  -0.083330   0.081935  -2.048438  -0.206856  -0.839563
# 41            0   0.435826   1.797289   0.363570  -0.005651   0.442866
# 43            0        NaN        NaN        NaN        NaN        NaN
# ...

# %%
tlist = df.timestamp.unique()
print len(tlist)
print sorted(tlist)
# Out:
# 1813
# ...

# %%
df2 = pd.DataFrame(df)

# %%
df2.fillna(df2.median())
# Out:
#            id  timestamp  derived_0  derived_1  derived_2  derived_3  \
# 0          10          0   0.370326  -0.006316   0.222831  -0.213030
# 1          11          0   0.014765  -0.038064  -0.017425   0.320652
# 2          12          0  -0.010622  -0.050577   3.379575  -0.157525
# 3          25          0  -0.000837   0.005523   0.021095   0.002476
# 4          26          0   0.176693  -0.025284  -0.057680   0.015100
# 5          27          0   0.346856   0.166239  -6.080701  -0.992249
# 6          31          0   0.072036   0.014931   0.021095   0.014063
# 7          38          0   0.300062   0.071251  -0.074451  -0.065292
# 8          39          0  -0.003511  -0.034270   0.082372  -0.023937
# 9          40          0  -0.083330   0.081935  -2.048438  -0.206856
# 10         41          0   0.435826   1.797289   0.363570  -0.005651
# 11         43          0  -0.000837   0.005523   0.021095   0.002476
# 12         44          0   0.034991  -0.019258   0.055769  -0.084496
# ...

# %%
sns.pairplot(df2, size=2, kind='scatter')
