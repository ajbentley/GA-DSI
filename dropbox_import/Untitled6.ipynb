# %%
import csv
print 'Opening File. Data: '
print ''
f = open('/Users/EKandTower/Dropbox/GA-DSI/sat_scores.csv','rU')
reader = csv.reader(f)
for row in reader:
    print row
print f.readline()
# Out:
# Opening File. Data:
#
# ['State', 'Rate', 'Verbal', 'Math']
# ['CT', '82', '509', '510']
# ['NJ', '81', '499', '513']
# ['MA', '79', '511', '515']
# ['NY', '77', '495', '505']
# ['NH', '72', '520', '516']
# ['RI', '71', '501', '499']
# ['PA', '71', '500', '499']
# ['VT', '69', '511', '506']
# ['ME', '69', '506', '500']
# ['VA', '68', '510', '501']
# ['DE', '67', '501', '499']
# ['MD', '65', '508', '510']
# ['NC', '65', '493', '499']
# ['GA', '63', '491', '489']
# ['IN', '60', '499', '501']
# ['SC', '57', '486', '488']
# ['DC', '56', '482', '474']
# ['OR', '55', '526', '526']
# ['FL', '54', '498', '499']
# ['WA', '53', '527', '527']
# ['TX', '53', '493', '499']
# ['HI', '52', '485', '515']
# ['AK', '51', '514', '510']
# ['CA', '51', '498', '517']
# ['AZ', '34', '523', '525']
# ['NV', '33', '509', '515']
# ['CO', '31', '539', '542']
# ['OH', '26', '534', '439']
# ['MT', '23', '539', '539']
# ['WV', '18', '527', '512']
# ['ID', '17', '543', '542']
# ['TN', '13', '562', '553']
# ['NM', '13', '551', '542']
# ['IL', '12', '576', '589']
# ['KY', '12', '550', '550']
# ['WY', '11', '547', '545']
# ['MI', '11', '561', '572']
# ['MN', '9', '580', '589']
# ['KS', '9', '577', '580']
# ['AL', '9', '559', '554']
# ['NE', '8', '562', '568']
# ['OK', '8', '567', '561']
# ['MO', '8', '577', '577']
# ['LA', '7', '564', '562']
# ['WI', '6', '584', '596']
# ['AR', '6', '562', '550']
# ['UT', '5', '575', '570']
# ['IA', '5', '593', '603']
# ['SD', '4', '577', '582']
# ['ND', '4', '592', '599']
# ['MS', '4', '566', '551']
# ['All', '45', '506', '514']

# %%
SAT_d = {}
for row in reader:
    SAT_d[row[0]]=row[1:3]
SAT_d
# Out:
# {}

# %%
import csv

f = open('/Users/EKandTower/Dropbox/GA-DSI/sat_scores.csv','rU')
reader = csv.reader(f)

# for row in reader:
#     print row

sat_d = {}
sat_s = []

for row in reader:
    key=row[0]
    dict_value=sat_d.get(key)
    
    if dict_value:
        dict_value.append[row]

    else:
        dict_value=[row]
    
    sat_d.update({key:dict_value})
    
sat_d
# Out:
# {'AK': [['AK', '51', '514', '510']],
#  'AL': [['AL', '9', '559', '554']],
#  'AR': [['AR', '6', '562', '550']],
#  'AZ': [['AZ', '34', '523', '525']],
#  'All': [['All', '45', '506', '514']],
#  'CA': [['CA', '51', '498', '517']],
#  'CO': [['CO', '31', '539', '542']],
#  'CT': [['CT', '82', '509', '510']],
#  'DC': [['DC', '56', '482', '474']],
#  'DE': [['DE', '67', '501', '499']],
#  'FL': [['FL', '54', '498', '499']],
#  'GA': [['GA', '63', '491', '489']],
#  'HI': [['HI', '52', '485', '515']],
#  'IA': [['IA', '5', '593', '603']],
#  'ID': [['ID', '17', '543', '542']],
#  'IL': [['IL', '12', '576', '589']],
#  'IN': [['IN', '60', '499', '501']],
#  'KS': [['KS', '9', '577', '580']],
#  'KY': [['KY', '12', '550', '550']],
#  'LA': [['LA', '7', '564', '562']],
#  'MA': [['MA', '79', '511', '515']],
#  'MD': [['MD', '65', '508', '510']],
#  'ME': [['ME', '69', '506', '500']],
#  'MI': [['MI', '11', '561', '572']],
#  'MN': [['MN', '9', '580', '589']],
#  'MO': [['MO', '8', '577', '577']],
#  'MS': [['MS', '4', '566', '551']],
#  'MT': [['MT', '23', '539', '539']],
#  'NC': [['NC', '65', '493', '499']],
#  'ND': [['ND', '4', '592', '599']],
#  'NE': [['NE', '8', '562', '568']],
#  'NH': [['NH', '72', '520', '516']],
#  'NJ': [['NJ', '81', '499', '513']],
#  'NM': [['NM', '13', '551', '542']],
#  'NV': [['NV', '33', '509', '515']],
#  'NY': [['NY', '77', '495', '505']],
#  'OH': [['OH', '26', '534', '439']],
#  'OK': [['OK', '8', '567', '561']],
#  'OR': [['OR', '55', '526', '526']],
#  'PA': [['PA', '71', '500', '499']],
#  'RI': [['RI', '71', '501', '499']],
#  'SC': [['SC', '57', '486', '488']],
#  'SD': [['SD', '4', '577', '582']],
#  'State': [['State', 'Rate', 'Verbal', 'Math']],
#  'TN': [['TN', '13', '562', '553']],
#  'TX': [['TX', '53', '493', '499']],
#  'UT': [['UT', '5', '575', '570']],
#  'VA': [['VA', '68', '510', '501']],
#  'VT': [['VT', '69', '511', '506']],
#  'WA': [['WA', '53', '527', '527']],
#  'WI': [['WI', '6', '584', '596']],
#  'WV': [['WV', '18', '527', '512']],
#  'WY': [['WY', '11', '547', '545']]}
