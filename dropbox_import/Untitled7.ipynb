# %%
import csv

f = open('/Users/EKandTower/Dropbox/GA-DSI/sat_scores.csv','rU')
reader = csv.reader(f)

sat_d = {}

for row in reader:
#    col1 = row[0]
#    col2 = row[1]
#    col3 = row[2]
#    col4 = row[3]
#    sat_d[col1]=col2, col3, col4
#    sat_d[row1] = row3
#    sat_d[row1] = row4

    sat_d.items()

sat_d.items()
# Out:
# []

# %%
# Creates a data dictionary for the dataset

print 'Step 1.3: create empty dictionary'
sat_d = {}
print''
print 'Empty dictionary created'
print''
print''

print 'Step 2.4: Load the data into a list of lists'
print''
import csv

f = open('/Users/EKandTower/Dropbox/GA-DSI/sat_scores.csv','rU')
reader = csv.reader(f)

print ''
print 'Data loaded'
print''
print''
print'Step 2.5: Print the data'
print''

for row in reader:
    print row

print''
print''
print'Step 2.6: Extract a list of the labels from the data, and remove them from the data'
print''
print'    To do this I rewrote the load code to skip the first row'
f = open('/Users/EKandTower/Dropbox/GA-DSI/sat_scores.csv','rU')

reader = csv.reader(f)
headers = [next(reader, None)]

print''
print'The headers are'

print headers

print''

for row in reader:
    print row

print 'check'
    
for row in reader:
    print row
    
print''
print''
print'Step 2.7: Create a list of State names extracted from the data. '

for row in reader:
    state_list = [item[0] for item in reader]
    print state_list

for row in reader:
    line_type = [type for item in reader]
    print line_type
# Out:
# Step 1.3: create empty dictionary
#
# Empty dictionary created
#
#
# Step 2.4: Load the data into a list of lists
#
#
# Data loaded
#
#
# Step 2.5: Print the data
#
# ['State', 'Rate', 'Verbal', 'Math']
# ['CT', '82', '509', '510']
# ['NJ', '81', '499', '513']
# ['MA', '79', '511', '515']
# ['NY', '77', '495', '505']
# ['NH', '72', '520', '516']
# ['RI', '71', '501', '499']
# ['PA', '71', '500', '499']
# ['VT', '69', '511', '506']
# ['ME', '69', '506', '500']
# ['VA', '68', '510', '501']
# ['DE', '67', '501', '499']
# ['MD', '65', '508', '510']
# ['NC', '65', '493', '499']
# ['GA', '63', '491', '489']
# ['IN', '60', '499', '501']
# ['SC', '57', '486', '488']
# ['DC', '56', '482', '474']
# ['OR', '55', '526', '526']
# ['FL', '54', '498', '499']
# ['WA', '53', '527', '527']
# ['TX', '53', '493', '499']
# ['HI', '52', '485', '515']
# ['AK', '51', '514', '510']
# ['CA', '51', '498', '517']
# ['AZ', '34', '523', '525']
# ['NV', '33', '509', '515']
# ['CO', '31', '539', '542']
# ['OH', '26', '534', '439']
# ['MT', '23', '539', '539']
# ['WV', '18', '527', '512']
# ['ID', '17', '543', '542']
# ['TN', '13', '562', '553']
# ['NM', '13', '551', '542']
# ['IL', '12', '576', '589']
# ['KY', '12', '550', '550']
# ['WY', '11', '547', '545']
# ['MI', '11', '561', '572']
# ['MN', '9', '580', '589']
# ['KS', '9', '577', '580']
# ['AL', '9', '559', '554']
# ['NE', '8', '562', '568']
# ['OK', '8', '567', '561']
# ['MO', '8', '577', '577']
# ['LA', '7', '564', '562']
# ['WI', '6', '584', '596']
# ['AR', '6', '562', '550']
# ['UT', '5', '575', '570']
# ['IA', '5', '593', '603']
# ['SD', '4', '577', '582']
# ['ND', '4', '592', '599']
# ['MS', '4', '566', '551']
# ['All', '45', '506', '514']
#
#
# Step 2.6: Extract a list of the labels from the data, and remove them from the data
#
#     To do this I rewrote the load code to skip the first row
#
# The headers are
# [['State', 'Rate', 'Verbal', 'Math']]
#
# ['CT', '82', '509', '510']
# ['NJ', '81', '499', '513']
# ['MA', '79', '511', '515']
# ['NY', '77', '495', '505']
# ['NH', '72', '520', '516']
# ['RI', '71', '501', '499']
# ['PA', '71', '500', '499']
# ['VT', '69', '511', '506']
# ['ME', '69', '506', '500']
# ['VA', '68', '510', '501']
# ['DE', '67', '501', '499']
# ['MD', '65', '508', '510']
# ['NC', '65', '493', '499']
# ['GA', '63', '491', '489']
# ['IN', '60', '499', '501']
# ['SC', '57', '486', '488']
# ['DC', '56', '482', '474']
# ['OR', '55', '526', '526']
# ['FL', '54', '498', '499']
# ['WA', '53', '527', '527']
# ['TX', '53', '493', '499']
# ['HI', '52', '485', '515']
# ['AK', '51', '514', '510']
# ['CA', '51', '498', '517']
# ['AZ', '34', '523', '525']
# ['NV', '33', '509', '515']
# ['CO', '31', '539', '542']
# ['OH', '26', '534', '439']
# ['MT', '23', '539', '539']
# ['WV', '18', '527', '512']
# ['ID', '17', '543', '542']
# ['TN', '13', '562', '553']
# ['NM', '13', '551', '542']
# ['IL', '12', '576', '589']
# ['KY', '12', '550', '550']
# ['WY', '11', '547', '545']
# ['MI', '11', '561', '572']
# ['MN', '9', '580', '589']
# ['KS', '9', '577', '580']
# ['AL', '9', '559', '554']
# ['NE', '8', '562', '568']
# ['OK', '8', '567', '561']
# ['MO', '8', '577', '577']
# ['LA', '7', '564', '562']
# ['WI', '6', '584', '596']
# ['AR', '6', '562', '550']
# ['UT', '5', '575', '570']
# ['IA', '5', '593', '603']
# ['SD', '4', '577', '582']
# ['ND', '4', '592', '599']
# ['MS', '4', '566', '551']
# ['All', '45', '506', '514']
# check
#
#
# Step 2.7: Create a list of State names extracted from the data.

# %%
print 'Step 2.4: Load the data into a list of lists'
print''

import csv

f = open('/Users/EKandTower/Dropbox/GA-DSI/sat_scores.csv','rU')
reader = csv.reader(f)

dict((x[0], (x[1], x[2])) for x in reader[1:])
# Out:
# Step 2.4: Load the data into a list of lists
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-75fac7ecd2f1> in <module>()
#       7 reader = csv.reader(f)
#       8
# ----> 9 dict((x[0], (x[1], x[2])) for x in reader[1:])
#
# TypeError: '_csv.reader' object has no attribute '__getitem__'
